# %%
# This program was original made by following along with Codemy.com tutorials on YouTube.
# Playlist here:
# https://youtube.com/playlist?list=PLCC34OHNcOtpcgR9LEYSdi9r7XIbpkpK1&si=qN9cA47jvIpXJ6Ez

# It has since been modified for use with the NASA Turbofan Jet Engine Data Set for a Machine Learning in ME course at UC Berkeley.

# %%
import torch # Import the PyTorch library
import torch.nn as nn # Import the neural network module from PyTorch for defining layers and loss functions
import torch.nn.functional as F # Import functional interface for operations like activation functions (ReLU)

# %%
# Create a Model Class that inherits nn.Module, the base class for all neural network modules in PyTorch
class Model(nn.Module):
  # Input layer (24 features of the Engine) -->
  # Hidden Layer1 (number of neurons) --> 128
  # H2 (n) --> 64
  # H3 (n) --> 32
  # H4 (n) --> 16
  # output (1 value for RUL prediction)
  def __init__(self, in_features=24, h1=128, h2=64, h3=32, h4=16, out_features=1, dropout=0.2):
    super().__init__() # instantiate our nn.Module, initializing the parent class
    self.fc1 = nn.Linear(in_features, h1) # Define the first fully connected (linear) layer: input -> h1
    #self.bn1 = nn.BatchNorm1d(h1) # Add batch normalization after fc1
    self.fc2 = nn.Linear(h1, h2) # Define the second fully connected layer: h1 -> h2
    #self.bn2 = nn.BatchNorm1d(h2) # Add batch normalization after fc2
    self.fc3 = nn.Linear(h2, h3) # Define the third fully connected layer: h2 -> h3
    #self.bn3 = nn.BatchNorm1d(h3) # Add batch normalization after fc3
    self.fc4 = nn.Linear(h3, h4) # Define the fourth fully connected layer: h3 -> h4
    #self.bn4 = nn.BatchNorm1d(h4) # Add batch normalization after fc4
    self.out = nn.Linear(h4, out_features) # Define the output layer: h4 -> output
    #self.dropout = nn.Dropout(dropout) # Dropout layer

  # Define the forward pass, which dictates how data moves through the network
  def forward(self, x):
    x = self.fc1(x) # Pass through fc1
    #x = self.bn1(x) # Apply batch normalization
    #x = F.relu(x) # Apply ReLU activation
    x = F.gelu(x) # Apply GELU activation
    #x = self.dropout(x) # Apply dropout
    
    x = self.fc2(x) # Pass through fc2
    #x = self.bn2(x) # Apply batch normalization
    x = F.gelu(x) # Apply GELU activation
    #x = F.gelu(x) # Apply GELU activation
    #x = self.dropout(x) # Apply dropout
    
    x = self.fc3(x) # Pass through fc3
    #x = self.bn3(x) # Apply batch normalization
    x = F.gelu(x) # Apply GELU activation
    #x = F.gelu(x) # Apply GELU activation
    #x = self.dropout(x) # Apply dropout
    
    x = self.fc4(x) # Pass through fc4
    #x = self.bn4(x) # Apply batch normalization
    x = F.gelu(x) # Apply GELU activation
    #x = F.gelu(x) # Apply GELU activation
    #x = self.dropout(x) # Apply dropout
    
    x = self.out(x) # Pass result through the output layer (no activation on output for regression)

    return x # Return the final output

# %%
# Pick a manual seed for randomization so results are reproducible
torch.manual_seed(69)
# Create an instance of our defined Model class
model = Model()

# %%
import pandas as pd # Import pandas for data manipulation (DataFrames)
import matplotlib.pyplot as plt # Import matplotlib for plotting graphs
# Magic command to display plots directly in the notebook cells
# %matplotlib inline

# %%
Training_df = pd.read_csv('Train4.csv') # Load the CSV data from the Train1.csv file into a pandas DataFrame

# %%
Training_df.tail()
# Out:
#        engine  cycle  op_set1  op_set2  op_set3  Fan Inlet Temperature  \
# 61244     249    251   9.9998   0.2500    100.0                 489.05
# 61245     249    252   0.0028   0.0015    100.0                 518.67
# 61246     249    253   0.0029   0.0000    100.0                 518.67
# 61247     249    254  35.0046   0.8400    100.0                 449.44
# 61248     249    255  42.0030   0.8400    100.0                 445.00
#
#        LPC Outlet Temperature  HPC Outlet Temperature  LPT Outlet Temperature  \
# 61244                  605.33                 1516.36                 1315.28
# 61245                  643.42                 1598.92                 1426.77
# 61246                  643.68                 1607.72                 1430.56
# 61247                  555.77                 1381.29                 1148.18
# 61248                  549.85                 1369.75                 1147.45
#
#        Fan Inlet Pressure  ...  Corrected Fan Speed  Corrected Core Speed  \
# 61244               10.52  ...              2388.73               8185.69
# 61245               14.62  ...              2388.46               8185.47
# 61246               14.62  ...              2388.48               8193.94
# 61247                5.48  ...              2388.83               8125.64
# 61248                3.91  ...              2388.66               8144.33
#
#        Bypass Ratio  Burner Fuel-Air Ratio  Bleed Enthalpy  \
# 61244        8.4541                   0.03             372
# 61245        8.2221                   0.03             396
# 61246        8.2525                   0.03             395
# 61247        9.0515                   0.02             337
# 61248        9.1207                   0.02             333
#
#        Required Fan Speed  Required Fan Conversion Speed  \
# 61244                2319                          100.0
# 61245                2388                          100.0
# 61246                2388                          100.0
# 61247                2223                          100.0
# 61248                2212                          100.0
#
#        High-Pressure Turbines Cool Air Flow  \
# 61244                                 29.11
# 61245                                 39.38
# 61246                                 39.78
# 61247                                 15.26
# 61248                                 10.66
#
#        Low-Pressure Turbines Cool Air Flow  RUL
# 61244                              17.5234  4.0
# 61245                              23.7151  3.0
# 61246                              23.8270  2.0
# 61247                               9.0774  1.0
# 61248                               6.4341  0.0
#
# [5 rows x 27 columns]

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Separate the feature columns (columns 3-26, which are indices 2-25 in 0-indexed)
feature_columns = Training_df.columns[2:26]  # This gets columns from index 2 to 25 (columns 3-26)

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Scale the feature columns to [0, 1]
Training_df[feature_columns] = scaler.fit_transform(Training_df[feature_columns])

print("Features scaled successfully!")
print(f"\nScaled data preview:")
print(Training_df.head())
print(f"\nMin values:\n{Training_df[feature_columns].min()}")
print(f"\nMax values:\n{Training_df[feature_columns].max()}")
# Out:
# Features scaled successfully!
#
# Scaled data preview:
#    engine  cycle   op_set1   op_set2  op_set3  Fan Inlet Temperature  \
# 0       1      1  0.999926  0.997625      1.0               0.000000
# 1       1      2  0.476147  0.831591      1.0               0.626985
# 2       1      3  0.999900  0.998694      1.0               0.000000
# 3       1      4  0.999810  0.997625      1.0               0.000000
# 4       1      5  0.595275  0.737173      0.0               0.238089
#
#    LPC Outlet Temperature  HPC Outlet Temperature  LPT Outlet Temperature  \
# 0                0.130347                0.272082                0.212586
# 1                0.647971                0.634407                0.511781
# 2                0.123646                0.271245                0.222481
# 3                0.121351                0.266168                0.224835
# 4                0.005691                0.033916                0.022025
#
#    Fan Inlet Pressure  ...  Corrected Fan Speed  Corrected Core Speed  \
# 0            0.000000  ...             0.993111              0.550773
# 1            0.507937  ...             0.992395              0.481761
# 2            0.000000  ...             0.993056              0.531031
# 3            0.000000  ...             0.993194              0.553707
# 4            0.293184  ...             0.001405              0.048140
#
#    Bypass Ratio  Burner Fuel-Air Ratio  Bleed Enthalpy  Required Fan Speed  \
# 0      0.400540                    0.0        0.288660            0.627907
# 1      0.351346                    0.0        0.608247            0.864693
# 2      0.423787                    0.0        0.278351            0.627907
# 3      0.401716                    0.0        0.268041            0.627907
# 4      0.920536                    0.0        0.030928            0.000000
#
#    Required Fan Conversion Speed  High-Pressure Turbines Cool Air Flow  \
# 0                            1.0                              0.015473
# 1                            1.0                              0.477968
# 2                            1.0                              0.010764
# 3                            1.0                              0.012782
# 4                            0.0                              0.130172
#
#    Low-Pressure Turbines Cool Air Flow    RUL
# 0                             0.015881  320.0
# 1                             0.481487  319.0
# 2                             0.018932  318.0
# 3                             0.018724  317.0
# 4                             0.145560  316.0
#
# [5 rows x 27 columns]
#
# Min values:
# op_set1                                 0.0
# op_set2                                 0.0
# op_set3                                 0.0
# Fan Inlet Temperature                   0.0
# LPC Outlet Temperature                  0.0
# HPC Outlet Temperature                  0.0
# LPT Outlet Temperature                  0.0
# Fan Inlet Pressure                      0.0
# Bypass-Duct Pressure                    0.0
# HPC Outlet Pressure                     0.0
# Physical Fan Speed                      0.0
# Physical Core Speed                     0.0
# Engine Pressure Ratio                   0.0
# HPC Outlet Static Pressure              0.0
# Ratio of Fuel Flow to Ps30              0.0
# Corrected Fan Speed                     0.0
# Corrected Core Speed                    0.0
# Bypass Ratio                            0.0
# Burner Fuel-Air Ratio                   0.0
# Bleed Enthalpy                          0.0
# Required Fan Speed                      0.0
# Required Fan Conversion Speed           0.0
# High-Pressure Turbines Cool Air Flow    0.0
# Low-Pressure Turbines Cool Air Flow     0.0
# dtype: float64
#
# Max values:
# op_set1                                 1.0
# op_set2                                 1.0
# op_set3                                 1.0
# Fan Inlet Temperature                   1.0
# LPC Outlet Temperature                  1.0
# HPC Outlet Temperature                  1.0
# LPT Outlet Temperature                  1.0
# Fan Inlet Pressure                      1.0
# Bypass-Duct Pressure                    1.0
# HPC Outlet Pressure                     1.0
# Physical Fan Speed                      1.0
# Physical Core Speed                     1.0
# Engine Pressure Ratio                   1.0
# HPC Outlet Static Pressure              1.0
# Ratio of Fuel Flow to Ps30              1.0
# Corrected Fan Speed                     1.0
# Corrected Core Speed                    1.0
# Bypass Ratio                            1.0
# Burner Fuel-Air Ratio                   1.0
# Bleed Enthalpy                          1.0
# Required Fan Speed                      1.0
# Required Fan Conversion Speed           1.0
# High-Pressure Turbines Cool Air Flow    1.0
# Low-Pressure Turbines Cool Air Flow     1.0
# dtype: float64

# %%
# Train Test Split!  Set X, y
X = Training_df.drop(['engine', 'cycle', 'RUL'], axis=1) # Create features matrix X by dropping the target column 'variety'
y = Training_df['RUL'] # Create target vector y containing only the 'variety' column

# %%
# Convert these pandas objects to numpy arrays for compatibility with PyTorch or further processing
X = X.values
y = y.values

# %%
# Load and process the test data
Testing_df = pd.read_csv('Test4.csv')

# Scale the test data features using the SAME scaler fitted on training data
Testing_df[feature_columns] = scaler.transform(Testing_df[feature_columns])

# Separate features and target for test data
X_test_data = Testing_df.drop(['engine', 'cycle', 'RUL'], axis=1)
y_test_data = Testing_df['RUL']

# Convert to numpy arrays
X_test_data = X_test_data.values
y_test_data = y_test_data.values

# Establish Training and Testing sets
X_train = X  # Training features
y_train = y  # Training targets
X_test = X_test_data  # Testing features
y_test = y_test_data  # Testing targets

print(f"Training set: {X_train.shape} samples")
print(f"Testing set: {X_test.shape} samples")
# Out:
# Training set: (61249, 24) samples
# Testing set: (41214, 24) samples

# %%
# Convert X features to float tensors, which are the standard data type for inputs in PyTorch
X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)

# %%
# Convert y labels to float tensors for regression (not LongTensor for classification)
y_train = torch.FloatTensor(y_train)
y_test = torch.FloatTensor(y_test)

# %%
# Set the criterion of model to measure the error, how far off the predictions are from the data
criterion = nn.MSELoss() # MSELoss (Mean Squared Error) is used for regression tasks
# Choose Adam Optimizer, lr = learning rate (if error doesn't go down after a bunch of iterations (epochs), lower our learning rate)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01) # Initialize optimizer to update model weights based on gradients

# %%
# Train our model!
# Epochs? (one run thru all the training data in our network)
epochs = 1000 # Define number of training iterations
losses = [] # List to store loss values for plotting later
for i in range(epochs): # Loop through the number of epochs
  # Go forward and get a prediction
  y_pred = model.forward(X_train) # Get predicted results by passing training data through the model

  # Measure the loss/error, gonna be high at first
  loss = criterion(y_pred.squeeze(), y_train) # Calculate loss by comparing predictions (y_pred) vs actual values (y_train)

  # Keep Track of our losses
  losses.append(loss.detach().numpy()) # Detach loss from graph to save memory and convert to numpy for storing

  # print every 10 epoch
  if i % 10 == 0:
    print(f'Epoch: {i} and loss: {loss}')

  # Do some back propagation: take the error rate of forward propagation and feed it back
  # thru the network to fine tune the weights
  optimizer.zero_grad() # Clear previous gradients
  loss.backward() # Calculate gradients (backpropagation)
  optimizer.step() # Update weights using the optimizer
# Out:
# Epoch: 0 and loss: 25884.43359375
# Epoch: 10 and loss: 20493.556640625
# Epoch: 20 and loss: 9905.416015625
# Epoch: 30 and loss: 8825.5205078125
# Epoch: 40 and loss: 8492.111328125
# Epoch: 50 and loss: 8295.5380859375
# Epoch: 60 and loss: 8151.89208984375
# Epoch: 70 and loss: 8072.73779296875
# Epoch: 80 and loss: 8021.11865234375
# Epoch: 90 and loss: 7954.32373046875
# Epoch: 100 and loss: 7837.015625
# Epoch: 110 and loss: 7621.44921875
# Epoch: 120 and loss: 7301.96337890625
# Epoch: 130 and loss: 6991.0791015625
# Epoch: 140 and loss: 6468.5263671875
# Epoch: 150 and loss: 6183.3330078125
# Epoch: 160 and loss: 5862.0693359375
# Epoch: 170 and loss: 5937.62109375
# Epoch: 180 and loss: 7705.62255859375
# Epoch: 190 and loss: 5957.39697265625
# Epoch: 200 and loss: 5736.8935546875
# Epoch: 210 and loss: 5442.59228515625
# Epoch: 220 and loss: 5069.330078125
# Epoch: 230 and loss: 5439.6552734375
# Epoch: 240 and loss: 5000.1162109375
# Epoch: 250 and loss: 4995.15283203125
# Epoch: 260 and loss: 4772.86474609375
# Epoch: 270 and loss: 4528.12060546875
# Epoch: 280 and loss: 5286.74658203125
# Epoch: 290 and loss: 5236.439453125
# Epoch: 300 and loss: 4949.68115234375
# Epoch: 310 and loss: 4607.26953125
# Epoch: 320 and loss: 4368.974609375
# Epoch: 330 and loss: 5241.73388671875
# Epoch: 340 and loss: 4584.31689453125
# Epoch: 350 and loss: 4159.931640625
# Epoch: 360 and loss: 4032.02880859375
# Epoch: 370 and loss: 4115.3759765625
# Epoch: 380 and loss: 3991.97998046875
# Epoch: 390 and loss: 6027.14404296875
# Epoch: 400 and loss: 3969.898681640625
# Epoch: 410 and loss: 3941.58984375
# Epoch: 420 and loss: 4071.215576171875
# Epoch: 430 and loss: 4037.17333984375
# Epoch: 440 and loss: 3886.30029296875
# Epoch: 450 and loss: 3803.122314453125
# Epoch: 460 and loss: 4972.40576171875
# Epoch: 470 and loss: 3814.048583984375
# Epoch: 480 and loss: 3819.212890625
# Epoch: 490 and loss: 3795.984619140625
# Epoch: 500 and loss: 3773.38623046875
# Epoch: 510 and loss: 3738.427490234375
# Epoch: 520 and loss: 3751.5048828125
# Epoch: 530 and loss: 3734.07958984375
# Epoch: 540 and loss: 3843.60546875
# Epoch: 550 and loss: 3760.720703125
# Epoch: 560 and loss: 3734.5234375
# Epoch: 570 and loss: 3768.93115234375
# Epoch: 580 and loss: 3865.113037109375
# Epoch: 590 and loss: 3726.731201171875
# Epoch: 600 and loss: 3725.694091796875
# Epoch: 610 and loss: 4148.91015625
# Epoch: 620 and loss: 3787.90673828125
# Epoch: 630 and loss: 3755.783447265625
# Epoch: 640 and loss: 3958.78173828125
# Epoch: 650 and loss: 3786.078125
# Epoch: 660 and loss: 3712.233642578125
# Epoch: 670 and loss: 3705.9169921875
# Epoch: 680 and loss: 4036.8955078125
# Epoch: 690 and loss: 3773.20166015625
# Epoch: 700 and loss: 3703.811279296875
# Epoch: 710 and loss: 3804.995849609375
# Epoch: 720 and loss: 3713.96435546875
# Epoch: 730 and loss: 3702.1005859375
# Epoch: 740 and loss: 3977.169921875
# Epoch: 750 and loss: 3705.060791015625
# Epoch: 760 and loss: 3726.843017578125
# Epoch: 770 and loss: 3901.136474609375
# Epoch: 780 and loss: 3687.56787109375
# Epoch: 790 and loss: 3685.39599609375
# Epoch: 800 and loss: 3721.164306640625
# Epoch: 810 and loss: 3908.213134765625
# Epoch: 820 and loss: 3695.35107421875
# Epoch: 830 and loss: 3797.0
# Epoch: 840 and loss: 3687.05322265625
# Epoch: 850 and loss: 3679.474609375
# Epoch: 860 and loss: 3772.71923828125
# Epoch: 870 and loss: 3707.586181640625
# Epoch: 880 and loss: 3731.5576171875
# Epoch: 890 and loss: 3806.6923828125
# Epoch: 900 and loss: 3714.19921875
# Epoch: 910 and loss: 3672.51806640625
# Epoch: 920 and loss: 4304.0986328125
# Epoch: 930 and loss: 3848.347412109375
# Epoch: 940 and loss: 3779.449951171875
# Epoch: 950 and loss: 3689.5234375
# Epoch: 960 and loss: 3668.16357421875
# Epoch: 970 and loss: 3683.789306640625
# Epoch: 980 and loss: 3742.47119140625
# Epoch: 990 and loss: 3660.714599609375

# %%
# Graph it out!
plt.plot(range(epochs), losses) # Plot the loss values over epochs
plt.ylabel("loss/error") # Label the y-axis
plt.xlabel('Epoch') # Label the x-axis
# Out:
# Text(0.5, 0, 'Epoch')

# %%
# Evaluate Model on Test Data Set (validate model on test set)
with torch.no_grad():  # Basically turn off back propogation (gradient calculation) to save memory and computation
  y_eval = model.forward(X_test) # X_test are features from our test set, y_eval will be predictions
  loss = criterion(y_eval.squeeze(), y_test) # Find the loss or error on the test set

print(f'Test Loss (MSE): {loss.item():.4f}')
# Out:
# Test Loss (MSE): 6028.6870

# %%
model.eval()  # Set model to evaluation mode
correct = 0
with torch.no_grad(): # Disable gradient calculation
  for i, data in enumerate(X_test): # Iterate over test data
    y_val = model.forward(data.unsqueeze(0)) # Add batch dimension: (24,) -> (1, 24)

    # Will tell us what RUL our network predicts
    print(f'{i+1}.)  Predicted: {y_val.item():.2f} \t Actual: {y_test[i].item():.2f}')

# Calculate accuracy metrics for regression
with torch.no_grad():
  y_pred_all = model.forward(X_test)
  mae = torch.mean(torch.abs(y_pred_all.squeeze() - y_test))
  print(f'\nMean Absolute Error: {mae.item():.2f}')
# Out:
# 1.)  Predicted: 254.16 	 Actual: 251.00
# 2.)  Predicted: 245.78 	 Actual: 250.00
# 3.)  Predicted: 253.87 	 Actual: 249.00
# 4.)  Predicted: 229.38 	 Actual: 248.00
# 5.)  Predicted: 235.32 	 Actual: 247.00
# 6.)  Predicted: 203.02 	 Actual: 246.00
# 7.)  Predicted: 247.09 	 Actual: 245.00
# 8.)  Predicted: 236.99 	 Actual: 244.00
# 9.)  Predicted: 232.72 	 Actual: 243.00
# 10.)  Predicted: 236.68 	 Actual: 242.00
# 11.)  Predicted: 219.79 	 Actual: 241.00
# 12.)  Predicted: 231.52 	 Actual: 240.00
# 13.)  Predicted: 246.40 	 Actual: 239.00
# 14.)  Predicted: 226.28 	 Actual: 238.00
# 15.)  Predicted: 241.80 	 Actual: 237.00
# 16.)  Predicted: 238.57 	 Actual: 236.00
# 17.)  Predicted: 233.89 	 Actual: 235.00
# 18.)  Predicted: 240.71 	 Actual: 234.00
# 19.)  Predicted: 221.19 	 Actual: 233.00
# 20.)  Predicted: 251.02 	 Actual: 232.00
# 21.)  Predicted: 239.34 	 Actual: 231.00
# 22.)  Predicted: 253.54 	 Actual: 230.00
# 23.)  Predicted: 225.96 	 Actual: 229.00
# 24.)  Predicted: 228.13 	 Actual: 228.00
# 25.)  Predicted: 256.98 	 Actual: 227.00
# 26.)  Predicted: 216.49 	 Actual: 226.00
# 27.)  Predicted: 212.69 	 Actual: 225.00
# 28.)  Predicted: 251.81 	 Actual: 224.00
# 29.)  Predicted: 210.02 	 Actual: 223.00
# 30.)  Predicted: 244.27 	 Actual: 222.00
# 31.)  Predicted: 228.68 	 Actual: 221.00
# 32.)  Predicted: 233.11 	 Actual: 220.00
# 33.)  Predicted: 252.12 	 Actual: 219.00
# 34.)  Predicted: 247.55 	 Actual: 218.00
# 35.)  Predicted: 263.59 	 Actual: 217.00
# 36.)  Predicted: 232.72 	 Actual: 216.00
# 37.)  Predicted: 238.37 	 Actual: 215.00
# 38.)  Predicted: 232.95 	 Actual: 214.00
# 39.)  Predicted: 223.84 	 Actual: 213.00
# 40.)  Predicted: 249.06 	 Actual: 212.00
# 41.)  Predicted: 224.48 	 Actual: 211.00
# 42.)  Predicted: 225.75 	 Actual: 210.00
# 43.)  Predicted: 238.48 	 Actual: 209.00
# 44.)  Predicted: 253.73 	 Actual: 208.00
# 45.)  Predicted: 213.96 	 Actual: 207.00
# 46.)  Predicted: 258.59 	 Actual: 206.00
# 47.)  Predicted: 224.36 	 Actual: 205.00
# 48.)  Predicted: 224.65 	 Actual: 204.00
# 49.)  Predicted: 252.48 	 Actual: 203.00
# 50.)  Predicted: 222.52 	 Actual: 202.00
# 51.)  Predicted: 232.01 	 Actual: 201.00
# 52.)  Predicted: 243.14 	 Actual: 200.00
# 53.)  Predicted: 237.26 	 Actual: 199.00
# 54.)  Predicted: 249.13 	 Actual: 198.00
# 55.)  Predicted: 232.67 	 Actual: 197.00
# 56.)  Predicted: 234.74 	 Actual: 196.00
# 57.)  Predicted: 234.60 	 Actual: 195.00
# 58.)  Predicted: 216.60 	 Actual: 194.00
# 59.)  Predicted: 233.94 	 Actual: 193.00
# 60.)  Predicted: 261.88 	 Actual: 192.00
# 61.)  Predicted: 235.71 	 Actual: 191.00
# 62.)  Predicted: 226.23 	 Actual: 190.00
# 63.)  Predicted: 248.68 	 Actual: 189.00
# 64.)  Predicted: 231.40 	 Actual: 188.00
# 65.)  Predicted: 228.84 	 Actual: 187.00
# 66.)  Predicted: 235.83 	 Actual: 186.00
# 67.)  Predicted: 237.21 	 Actual: 185.00
# 68.)  Predicted: 240.88 	 Actual: 184.00
# 69.)  Predicted: 214.49 	 Actual: 183.00
# 70.)  Predicted: 236.62 	 Actual: 182.00
# 71.)  Predicted: 225.06 	 Actual: 181.00
# 72.)  Predicted: 206.84 	 Actual: 180.00
# 73.)  Predicted: 253.17 	 Actual: 179.00
# 74.)  Predicted: 204.94 	 Actual: 178.00
# 75.)  Predicted: 252.39 	 Actual: 177.00
# 76.)  Predicted: 243.99 	 Actual: 176.00
# 77.)  Predicted: 221.01 	 Actual: 175.00
# 78.)  Predicted: 210.77 	 Actual: 174.00
# 79.)  Predicted: 243.13 	 Actual: 173.00
# 80.)  Predicted: 222.02 	 Actual: 172.00
# 81.)  Predicted: 228.32 	 Actual: 171.00
# 82.)  Predicted: 236.52 	 Actual: 170.00
# 83.)  Predicted: 224.87 	 Actual: 169.00
# 84.)  Predicted: 214.33 	 Actual: 168.00
# 85.)  Predicted: 211.60 	 Actual: 167.00
# 86.)  Predicted: 234.07 	 Actual: 166.00
# 87.)  Predicted: 229.31 	 Actual: 165.00
# 88.)  Predicted: 227.67 	 Actual: 164.00
# 89.)  Predicted: 229.20 	 Actual: 163.00
# 90.)  Predicted: 225.38 	 Actual: 162.00
# 91.)  Predicted: 236.20 	 Actual: 161.00
# 92.)  Predicted: 223.27 	 Actual: 160.00
# 93.)  Predicted: 226.08 	 Actual: 159.00
# 94.)  Predicted: 226.85 	 Actual: 158.00
# 95.)  Predicted: 226.27 	 Actual: 157.00
# 96.)  Predicted: 205.00 	 Actual: 156.00
# 97.)  Predicted: 217.14 	 Actual: 155.00
# 98.)  Predicted: 238.50 	 Actual: 154.00
# 99.)  Predicted: 215.90 	 Actual: 153.00
# 100.)  Predicted: 257.24 	 Actual: 152.00
# 101.)  Predicted: 213.19 	 Actual: 151.00
# 102.)  Predicted: 211.12 	 Actual: 150.00
# 103.)  Predicted: 246.59 	 Actual: 149.00
# 104.)  Predicted: 231.74 	 Actual: 148.00
# 105.)  Predicted: 216.97 	 Actual: 147.00
# 106.)  Predicted: 234.80 	 Actual: 146.00
# 107.)  Predicted: 227.03 	 Actual: 145.00
# 108.)  Predicted: 226.94 	 Actual: 144.00
# 109.)  Predicted: 241.62 	 Actual: 143.00
# 110.)  Predicted: 222.87 	 Actual: 142.00
# 111.)  Predicted: 217.01 	 Actual: 141.00
# 112.)  Predicted: 235.42 	 Actual: 140.00
# 113.)  Predicted: 228.48 	 Actual: 139.00
# 114.)  Predicted: 245.24 	 Actual: 138.00
# 115.)  Predicted: 234.81 	 Actual: 137.00
# 116.)  Predicted: 220.00 	 Actual: 136.00
# 117.)  Predicted: 239.19 	 Actual: 135.00
# 118.)  Predicted: 218.20 	 Actual: 134.00
# 119.)  Predicted: 234.67 	 Actual: 133.00
# 120.)  Predicted: 209.32 	 Actual: 132.00
# 121.)  Predicted: 212.64 	 Actual: 131.00
# 122.)  Predicted: 229.17 	 Actual: 130.00
# 123.)  Predicted: 222.39 	 Actual: 129.00
# 124.)  Predicted: 221.13 	 Actual: 128.00
# 125.)  Predicted: 216.30 	 Actual: 127.00
# 126.)  Predicted: 233.85 	 Actual: 126.00
# 127.)  Predicted: 218.60 	 Actual: 125.00
# 128.)  Predicted: 243.05 	 Actual: 124.00
# 129.)  Predicted: 224.72 	 Actual: 123.00
# 130.)  Predicted: 209.02 	 Actual: 122.00
# 131.)  Predicted: 225.18 	 Actual: 121.00
# 132.)  Predicted: 248.68 	 Actual: 120.00
# 133.)  Predicted: 212.04 	 Actual: 119.00
# 134.)  Predicted: 217.70 	 Actual: 118.00
# 135.)  Predicted: 228.80 	 Actual: 117.00
# 136.)  Predicted: 199.56 	 Actual: 116.00
# 137.)  Predicted: 255.69 	 Actual: 115.00
# 138.)  Predicted: 197.38 	 Actual: 114.00
# 139.)  Predicted: 223.80 	 Actual: 113.00
# 140.)  Predicted: 205.32 	 Actual: 112.00
# 141.)  Predicted: 234.43 	 Actual: 111.00
# 142.)  Predicted: 219.56 	 Actual: 110.00
# 143.)  Predicted: 235.04 	 Actual: 109.00
# 144.)  Predicted: 208.47 	 Actual: 108.00
# 145.)  Predicted: 214.42 	 Actual: 107.00
# 146.)  Predicted: 186.30 	 Actual: 106.00
# 147.)  Predicted: 221.14 	 Actual: 105.00
# 148.)  Predicted: 218.59 	 Actual: 104.00
# 149.)  Predicted: 227.13 	 Actual: 103.00
# 150.)  Predicted: 199.04 	 Actual: 102.00
# 151.)  Predicted: 220.34 	 Actual: 101.00
# 152.)  Predicted: 210.24 	 Actual: 100.00
# 153.)  Predicted: 208.91 	 Actual: 99.00
# 154.)  Predicted: 194.48 	 Actual: 98.00
# 155.)  Predicted: 207.82 	 Actual: 97.00
# 156.)  Predicted: 200.98 	 Actual: 96.00
# 157.)  Predicted: 185.80 	 Actual: 95.00
# 158.)  Predicted: 214.70 	 Actual: 94.00
# 159.)  Predicted: 229.78 	 Actual: 93.00
# 160.)  Predicted: 201.65 	 Actual: 92.00
# 161.)  Predicted: 217.98 	 Actual: 91.00
# 162.)  Predicted: 192.55 	 Actual: 90.00
# 163.)  Predicted: 190.74 	 Actual: 89.00
# 164.)  Predicted: 206.05 	 Actual: 88.00
# 165.)  Predicted: 193.74 	 Actual: 87.00
# 166.)  Predicted: 220.07 	 Actual: 86.00
# 167.)  Predicted: 205.11 	 Actual: 85.00
# 168.)  Predicted: 218.13 	 Actual: 84.00
# 169.)  Predicted: 218.97 	 Actual: 83.00
# 170.)  Predicted: 181.66 	 Actual: 82.00
# 171.)  Predicted: 198.39 	 Actual: 81.00
# 172.)  Predicted: 188.19 	 Actual: 80.00
# 173.)  Predicted: 217.58 	 Actual: 79.00
# 174.)  Predicted: 194.78 	 Actual: 78.00
# 175.)  Predicted: 209.75 	 Actual: 77.00
# 176.)  Predicted: 192.46 	 Actual: 76.00
# 177.)  Predicted: 200.03 	 Actual: 75.00
# 178.)  Predicted: 192.36 	 Actual: 74.00
# 179.)  Predicted: 189.45 	 Actual: 73.00
# 180.)  Predicted: 199.52 	 Actual: 72.00
# 181.)  Predicted: 180.09 	 Actual: 71.00
# 182.)  Predicted: 170.72 	 Actual: 70.00
# 183.)  Predicted: 192.35 	 Actual: 69.00
# 184.)  Predicted: 179.87 	 Actual: 68.00
# 185.)  Predicted: 175.43 	 Actual: 67.00
# 186.)  Predicted: 179.60 	 Actual: 66.00
# 187.)  Predicted: 180.66 	 Actual: 65.00
# 188.)  Predicted: 119.10 	 Actual: 64.00
# 189.)  Predicted: 197.17 	 Actual: 63.00
# 190.)  Predicted: 172.84 	 Actual: 62.00
# 191.)  Predicted: 122.13 	 Actual: 61.00
# 192.)  Predicted: 170.63 	 Actual: 60.00
# 193.)  Predicted: 150.52 	 Actual: 59.00
# 194.)  Predicted: 176.62 	 Actual: 58.00
# 195.)  Predicted: 158.15 	 Actual: 57.00
# 196.)  Predicted: 130.76 	 Actual: 56.00
# 197.)  Predicted: 185.98 	 Actual: 55.00
# 198.)  Predicted: 175.94 	 Actual: 54.00
# 199.)  Predicted: 132.03 	 Actual: 53.00
# 200.)  Predicted: 156.96 	 Actual: 52.00
# 201.)  Predicted: 140.31 	 Actual: 51.00
# 202.)  Predicted: 135.55 	 Actual: 50.00
# 203.)  Predicted: 108.29 	 Actual: 49.00
# 204.)  Predicted: 120.18 	 Actual: 48.00
# 205.)  Predicted: 148.63 	 Actual: 47.00
# 206.)  Predicted: 121.46 	 Actual: 46.00
# 207.)  Predicted: 136.83 	 Actual: 45.00
# 208.)  Predicted: 127.74 	 Actual: 44.00
# 209.)  Predicted: 146.97 	 Actual: 43.00
# 210.)  Predicted: 143.62 	 Actual: 42.00
# 211.)  Predicted: 122.85 	 Actual: 41.00
# 212.)  Predicted: 137.94 	 Actual: 40.00
# 213.)  Predicted: 108.88 	 Actual: 39.00
# 214.)  Predicted: 120.25 	 Actual: 38.00
# 215.)  Predicted: 99.33 	 Actual: 37.00
# 216.)  Predicted: 117.47 	 Actual: 36.00
# 217.)  Predicted: 119.54 	 Actual: 35.00
# 218.)  Predicted: 106.79 	 Actual: 34.00
# 219.)  Predicted: 122.70 	 Actual: 33.00
# 220.)  Predicted: 82.48 	 Actual: 32.00
# 221.)  Predicted: 57.65 	 Actual: 31.00
# 222.)  Predicted: 78.53 	 Actual: 30.00
# 223.)  Predicted: 71.08 	 Actual: 29.00
# 224.)  Predicted: 78.47 	 Actual: 28.00
# 225.)  Predicted: 120.57 	 Actual: 27.00
# 226.)  Predicted: 55.63 	 Actual: 26.00
# 227.)  Predicted: 36.33 	 Actual: 25.00
# 228.)  Predicted: 45.46 	 Actual: 24.00
# 229.)  Predicted: 61.35 	 Actual: 23.00
# 230.)  Predicted: 70.66 	 Actual: 22.00
# 231.)  Predicted: 166.84 	 Actual: 191.00
# 232.)  Predicted: 144.54 	 Actual: 190.00
# 233.)  Predicted: 169.63 	 Actual: 189.00
# 234.)  Predicted: 181.10 	 Actual: 188.00
# 235.)  Predicted: 165.13 	 Actual: 187.00
# 236.)  Predicted: 167.67 	 Actual: 186.00
# 237.)  Predicted: 167.54 	 Actual: 185.00
# 238.)  Predicted: 152.62 	 Actual: 184.00
# 239.)  Predicted: 193.84 	 Actual: 183.00
# 240.)  Predicted: 162.01 	 Actual: 182.00
# 241.)  Predicted: 168.90 	 Actual: 181.00
# 242.)  Predicted: 177.87 	 Actual: 180.00
# 243.)  Predicted: 146.49 	 Actual: 179.00
# 244.)  Predicted: 164.82 	 Actual: 178.00
# 245.)  Predicted: 152.76 	 Actual: 177.00
# 246.)  Predicted: 184.46 	 Actual: 176.00
# 247.)  Predicted: 177.89 	 Actual: 175.00
# 248.)  Predicted: 183.08 	 Actual: 174.00
# 249.)  Predicted: 150.62 	 Actual: 173.00
# 250.)  Predicted: 154.99 	 Actual: 172.00
# 251.)  Predicted: 174.61 	 Actual: 171.00
# 252.)  Predicted: 169.94 	 Actual: 170.00
# 253.)  Predicted: 120.79 	 Actual: 169.00
# 254.)  Predicted: 184.61 	 Actual: 168.00
# 255.)  Predicted: 179.70 	 Actual: 167.00
# 256.)  Predicted: 187.05 	 Actual: 166.00
# 257.)  Predicted: 158.44 	 Actual: 165.00
# 258.)  Predicted: 152.45 	 Actual: 164.00
# 259.)  Predicted: 144.86 	 Actual: 163.00
# 260.)  Predicted: 187.23 	 Actual: 162.00
# 261.)  Predicted: 191.33 	 Actual: 161.00
# 262.)  Predicted: 150.98 	 Actual: 160.00
# 263.)  Predicted: 171.21 	 Actual: 159.00
# 264.)  Predicted: 158.14 	 Actual: 158.00
# 265.)  Predicted: 183.80 	 Actual: 157.00
# 266.)  Predicted: 206.81 	 Actual: 156.00
# 267.)  Predicted: 175.37 	 Actual: 155.00
# 268.)  Predicted: 149.08 	 Actual: 154.00
# 269.)  Predicted: 160.15 	 Actual: 153.00
# 270.)  Predicted: 134.23 	 Actual: 152.00
# 271.)  Predicted: 145.93 	 Actual: 151.00
# 272.)  Predicted: 144.56 	 Actual: 150.00
# 273.)  Predicted: 172.33 	 Actual: 149.00
# 274.)  Predicted: 180.47 	 Actual: 148.00
# 275.)  Predicted: 172.79 	 Actual: 147.00
# 276.)  Predicted: 171.88 	 Actual: 146.00
# 277.)  Predicted: 152.02 	 Actual: 145.00
# 278.)  Predicted: 139.08 	 Actual: 144.00
# 279.)  Predicted: 157.29 	 Actual: 143.00
# 280.)  Predicted: 172.26 	 Actual: 142.00
# 281.)  Predicted: 169.17 	 Actual: 141.00
# 282.)  Predicted: 176.91 	 Actual: 140.00
# 283.)  Predicted: 192.33 	 Actual: 139.00
# 284.)  Predicted: 178.56 	 Actual: 138.00
# 285.)  Predicted: 151.56 	 Actual: 137.00
# 286.)  Predicted: 184.77 	 Actual: 136.00
# 287.)  Predicted: 184.44 	 Actual: 135.00
# 288.)  Predicted: 156.86 	 Actual: 134.00
# 289.)  Predicted: 175.03 	 Actual: 133.00
# 290.)  Predicted: 162.83 	 Actual: 132.00
# 291.)  Predicted: 166.91 	 Actual: 131.00
# 292.)  Predicted: 169.79 	 Actual: 130.00
# 293.)  Predicted: 162.34 	 Actual: 129.00
# 294.)  Predicted: 158.37 	 Actual: 128.00
# 295.)  Predicted: 165.65 	 Actual: 127.00
# 296.)  Predicted: 155.41 	 Actual: 126.00
# 297.)  Predicted: 144.35 	 Actual: 125.00
# 298.)  Predicted: 152.25 	 Actual: 124.00
# 299.)  Predicted: 148.24 	 Actual: 123.00
# 300.)  Predicted: 161.61 	 Actual: 122.00
# 301.)  Predicted: 141.07 	 Actual: 121.00
# 302.)  Predicted: 155.41 	 Actual: 120.00
# 303.)  Predicted: 84.58 	 Actual: 119.00
# 304.)  Predicted: 153.67 	 Actual: 118.00
# 305.)  Predicted: 158.94 	 Actual: 117.00
# 306.)  Predicted: 149.47 	 Actual: 116.00
# 307.)  Predicted: 125.48 	 Actual: 115.00
# 308.)  Predicted: 181.73 	 Actual: 114.00
# 309.)  Predicted: 128.84 	 Actual: 113.00
# 310.)  Predicted: 171.80 	 Actual: 112.00
# 311.)  Predicted: 165.96 	 Actual: 111.00
# 312.)  Predicted: 162.49 	 Actual: 110.00
# 313.)  Predicted: 145.18 	 Actual: 109.00
# 314.)  Predicted: 163.86 	 Actual: 108.00
# 315.)  Predicted: 149.47 	 Actual: 107.00
# 316.)  Predicted: 164.80 	 Actual: 106.00
# 317.)  Predicted: 164.70 	 Actual: 105.00
# 318.)  Predicted: 157.25 	 Actual: 104.00
# 319.)  Predicted: 127.79 	 Actual: 103.00
# 320.)  Predicted: 151.96 	 Actual: 102.00
# 321.)  Predicted: 116.58 	 Actual: 101.00
# 322.)  Predicted: 150.73 	 Actual: 100.00
# 323.)  Predicted: 141.38 	 Actual: 99.00
# 324.)  Predicted: 167.56 	 Actual: 98.00
# 325.)  Predicted: 147.43 	 Actual: 97.00
# 326.)  Predicted: 183.06 	 Actual: 96.00
# 327.)  Predicted: 161.45 	 Actual: 95.00
# 328.)  Predicted: 134.00 	 Actual: 94.00
# 329.)  Predicted: 171.88 	 Actual: 93.00
# 330.)  Predicted: 141.51 	 Actual: 92.00
# 331.)  Predicted: 146.82 	 Actual: 91.00
# 332.)  Predicted: 141.38 	 Actual: 90.00
# 333.)  Predicted: 168.42 	 Actual: 89.00
# 334.)  Predicted: 132.94 	 Actual: 88.00
# 335.)  Predicted: 171.65 	 Actual: 87.00
# 336.)  Predicted: 151.94 	 Actual: 86.00
# 337.)  Predicted: 153.53 	 Actual: 85.00
# 338.)  Predicted: 133.14 	 Actual: 84.00
# 339.)  Predicted: 142.08 	 Actual: 83.00
# 340.)  Predicted: 133.21 	 Actual: 82.00
# 341.)  Predicted: 131.36 	 Actual: 81.00
# 342.)  Predicted: 128.83 	 Actual: 80.00
# 343.)  Predicted: 122.50 	 Actual: 79.00
# 344.)  Predicted: 141.37 	 Actual: 78.00
# 345.)  Predicted: 109.27 	 Actual: 77.00
# 346.)  Predicted: 154.47 	 Actual: 76.00
# 347.)  Predicted: 122.43 	 Actual: 75.00
# 348.)  Predicted: 103.93 	 Actual: 74.00
# 349.)  Predicted: 126.64 	 Actual: 73.00
# 350.)  Predicted: 140.99 	 Actual: 72.00
# 351.)  Predicted: 121.66 	 Actual: 71.00
# 352.)  Predicted: 128.91 	 Actual: 70.00
# 353.)  Predicted: 119.19 	 Actual: 69.00
# 354.)  Predicted: 124.81 	 Actual: 68.00
# 355.)  Predicted: 132.90 	 Actual: 67.00
# 356.)  Predicted: 141.32 	 Actual: 66.00
# 357.)  Predicted: 112.60 	 Actual: 65.00
# 358.)  Predicted: 134.44 	 Actual: 64.00
# 359.)  Predicted: 107.79 	 Actual: 63.00
# 360.)  Predicted: 94.82 	 Actual: 62.00
# 361.)  Predicted: 130.50 	 Actual: 61.00
# 362.)  Predicted: 124.76 	 Actual: 60.00
# 363.)  Predicted: 113.01 	 Actual: 59.00
# 364.)  Predicted: 141.92 	 Actual: 58.00
# 365.)  Predicted: 113.93 	 Actual: 57.00
# 366.)  Predicted: 115.49 	 Actual: 56.00
# 367.)  Predicted: 128.46 	 Actual: 55.00
# 368.)  Predicted: 64.61 	 Actual: 54.00
# 369.)  Predicted: 111.82 	 Actual: 53.00
# 370.)  Predicted: 161.22 	 Actual: 52.00
# 371.)  Predicted: 120.78 	 Actual: 51.00
# 372.)  Predicted: 105.85 	 Actual: 50.00
# 373.)  Predicted: 134.66 	 Actual: 49.00
# 374.)  Predicted: 64.56 	 Actual: 48.00
# 375.)  Predicted: 82.10 	 Actual: 47.00
# 376.)  Predicted: 123.40 	 Actual: 46.00
# 377.)  Predicted: 135.97 	 Actual: 45.00
# 378.)  Predicted: 86.72 	 Actual: 44.00
# 379.)  Predicted: 113.94 	 Actual: 43.00
# 380.)  Predicted: 85.31 	 Actual: 42.00
# 381.)  Predicted: 80.88 	 Actual: 41.00
# 382.)  Predicted: 94.04 	 Actual: 40.00
# 383.)  Predicted: 106.79 	 Actual: 39.00
# 384.)  Predicted: 186.46 	 Actual: 247.00
# 385.)  Predicted: 189.50 	 Actual: 246.00
# 386.)  Predicted: 187.72 	 Actual: 245.00
# 387.)  Predicted: 195.79 	 Actual: 244.00
# 388.)  Predicted: 204.07 	 Actual: 243.00
# 389.)  Predicted: 199.53 	 Actual: 242.00
# 390.)  Predicted: 185.38 	 Actual: 241.00
# 391.)  Predicted: 179.99 	 Actual: 240.00
# 392.)  Predicted: 196.55 	 Actual: 239.00
# 393.)  Predicted: 173.61 	 Actual: 238.00
# 394.)  Predicted: 192.52 	 Actual: 237.00
# 395.)  Predicted: 210.16 	 Actual: 236.00
# 396.)  Predicted: 206.78 	 Actual: 235.00
# 397.)  Predicted: 203.23 	 Actual: 234.00
# 398.)  Predicted: 203.75 	 Actual: 233.00
# 399.)  Predicted: 220.08 	 Actual: 232.00
# 400.)  Predicted: 215.60 	 Actual: 231.00
# 401.)  Predicted: 187.42 	 Actual: 230.00
# 402.)  Predicted: 193.96 	 Actual: 229.00
# 403.)  Predicted: 189.21 	 Actual: 228.00
# 404.)  Predicted: 200.20 	 Actual: 227.00
# 405.)  Predicted: 202.81 	 Actual: 226.00
# 406.)  Predicted: 166.88 	 Actual: 225.00
# 407.)  Predicted: 152.91 	 Actual: 224.00
# 408.)  Predicted: 176.72 	 Actual: 223.00
# 409.)  Predicted: 195.18 	 Actual: 222.00
# 410.)  Predicted: 199.16 	 Actual: 221.00
# 411.)  Predicted: 200.51 	 Actual: 220.00
# 412.)  Predicted: 199.05 	 Actual: 219.00
# 413.)  Predicted: 210.57 	 Actual: 218.00
# 414.)  Predicted: 176.74 	 Actual: 217.00
# 415.)  Predicted: 216.99 	 Actual: 216.00
# 416.)  Predicted: 186.29 	 Actual: 215.00
# 417.)  Predicted: 200.01 	 Actual: 214.00
# 418.)  Predicted: 209.38 	 Actual: 213.00
# 419.)  Predicted: 164.31 	 Actual: 212.00
# 420.)  Predicted: 177.47 	 Actual: 211.00
# 421.)  Predicted: 215.02 	 Actual: 210.00
# 422.)  Predicted: 204.42 	 Actual: 209.00
# 423.)  Predicted: 196.23 	 Actual: 208.00
# 424.)  Predicted: 197.55 	 Actual: 207.00
# 425.)  Predicted: 192.09 	 Actual: 206.00
# 426.)  Predicted: 181.87 	 Actual: 205.00
# 427.)  Predicted: 191.95 	 Actual: 204.00
# 428.)  Predicted: 180.66 	 Actual: 203.00
# 429.)  Predicted: 194.91 	 Actual: 202.00
# 430.)  Predicted: 200.43 	 Actual: 201.00
# 431.)  Predicted: 164.26 	 Actual: 200.00
# 432.)  Predicted: 194.55 	 Actual: 199.00
# 433.)  Predicted: 188.30 	 Actual: 198.00
# 434.)  Predicted: 190.62 	 Actual: 197.00
# 435.)  Predicted: 194.08 	 Actual: 196.00
# 436.)  Predicted: 206.36 	 Actual: 195.00
# 437.)  Predicted: 188.45 	 Actual: 194.00
# 438.)  Predicted: 215.45 	 Actual: 193.00
# 439.)  Predicted: 191.69 	 Actual: 192.00
# 440.)  Predicted: 207.33 	 Actual: 191.00
# 441.)  Predicted: 208.75 	 Actual: 190.00
# 442.)  Predicted: 168.12 	 Actual: 189.00
# 443.)  Predicted: 187.72 	 Actual: 188.00
# 444.)  Predicted: 175.60 	 Actual: 187.00
# 445.)  Predicted: 146.99 	 Actual: 186.00
# 446.)  Predicted: 204.25 	 Actual: 185.00
# 447.)  Predicted: 192.60 	 Actual: 184.00
# 448.)  Predicted: 180.41 	 Actual: 183.00
# 449.)  Predicted: 188.34 	 Actual: 182.00
# 450.)  Predicted: 174.00 	 Actual: 181.00
# 451.)  Predicted: 201.75 	 Actual: 180.00
# 452.)  Predicted: 200.96 	 Actual: 179.00
# 453.)  Predicted: 202.53 	 Actual: 178.00
# 454.)  Predicted: 210.94 	 Actual: 177.00
# 455.)  Predicted: 199.43 	 Actual: 176.00
# 456.)  Predicted: 216.50 	 Actual: 175.00
# 457.)  Predicted: 199.55 	 Actual: 174.00
# 458.)  Predicted: 197.24 	 Actual: 173.00
# 459.)  Predicted: 222.80 	 Actual: 172.00
# 460.)  Predicted: 187.26 	 Actual: 171.00
# 461.)  Predicted: 185.62 	 Actual: 170.00
# 462.)  Predicted: 201.75 	 Actual: 169.00
# 463.)  Predicted: 175.53 	 Actual: 168.00
# 464.)  Predicted: 191.82 	 Actual: 167.00
# 465.)  Predicted: 151.49 	 Actual: 166.00
# 466.)  Predicted: 189.69 	 Actual: 165.00
# 467.)  Predicted: 200.00 	 Actual: 164.00
# 468.)  Predicted: 183.35 	 Actual: 163.00
# 469.)  Predicted: 196.31 	 Actual: 162.00
# 470.)  Predicted: 195.90 	 Actual: 161.00
# 471.)  Predicted: 207.21 	 Actual: 160.00
# 472.)  Predicted: 176.70 	 Actual: 159.00
# 473.)  Predicted: 179.68 	 Actual: 158.00
# 474.)  Predicted: 179.41 	 Actual: 157.00
# 475.)  Predicted: 187.74 	 Actual: 156.00
# 476.)  Predicted: 210.31 	 Actual: 155.00
# 477.)  Predicted: 195.28 	 Actual: 154.00
# 478.)  Predicted: 183.37 	 Actual: 153.00
# 479.)  Predicted: 180.66 	 Actual: 152.00
# 480.)  Predicted: 188.01 	 Actual: 151.00
# 481.)  Predicted: 181.86 	 Actual: 150.00
# 482.)  Predicted: 191.40 	 Actual: 149.00
# 483.)  Predicted: 190.25 	 Actual: 148.00
# 484.)  Predicted: 179.05 	 Actual: 147.00
# 485.)  Predicted: 168.86 	 Actual: 146.00
# 486.)  Predicted: 172.86 	 Actual: 145.00
# 487.)  Predicted: 182.51 	 Actual: 144.00
# 488.)  Predicted: 184.16 	 Actual: 143.00
# 489.)  Predicted: 200.54 	 Actual: 142.00
# 490.)  Predicted: 182.40 	 Actual: 141.00
# 491.)  Predicted: 202.23 	 Actual: 140.00
# 492.)  Predicted: 167.60 	 Actual: 139.00
# 493.)  Predicted: 186.09 	 Actual: 138.00
# 494.)  Predicted: 193.74 	 Actual: 137.00
# 495.)  Predicted: 211.06 	 Actual: 136.00
# 496.)  Predicted: 176.61 	 Actual: 135.00
# 497.)  Predicted: 204.70 	 Actual: 134.00
# 498.)  Predicted: 202.54 	 Actual: 133.00
# 499.)  Predicted: 196.16 	 Actual: 132.00
# 500.)  Predicted: 186.88 	 Actual: 131.00
# 501.)  Predicted: 143.80 	 Actual: 130.00
# 502.)  Predicted: 191.96 	 Actual: 129.00
# 503.)  Predicted: 176.81 	 Actual: 128.00
# 504.)  Predicted: 186.44 	 Actual: 127.00
# 505.)  Predicted: 182.23 	 Actual: 126.00
# 506.)  Predicted: 184.46 	 Actual: 125.00
# 507.)  Predicted: 180.98 	 Actual: 124.00
# 508.)  Predicted: 172.19 	 Actual: 123.00
# 509.)  Predicted: 160.84 	 Actual: 122.00
# 510.)  Predicted: 183.18 	 Actual: 121.00
# 511.)  Predicted: 188.19 	 Actual: 120.00
# 512.)  Predicted: 186.24 	 Actual: 119.00
# 513.)  Predicted: 197.02 	 Actual: 118.00
# 514.)  Predicted: 207.75 	 Actual: 117.00
# 515.)  Predicted: 173.03 	 Actual: 116.00
# 516.)  Predicted: 179.17 	 Actual: 115.00
# 517.)  Predicted: 151.88 	 Actual: 114.00
# 518.)  Predicted: 169.63 	 Actual: 113.00
# 519.)  Predicted: 155.28 	 Actual: 112.00
# 520.)  Predicted: 177.75 	 Actual: 111.00
# 521.)  Predicted: 188.85 	 Actual: 110.00
# 522.)  Predicted: 153.33 	 Actual: 109.00
# 523.)  Predicted: 176.16 	 Actual: 108.00
# 524.)  Predicted: 171.25 	 Actual: 107.00
# 525.)  Predicted: 253.11 	 Actual: 282.00
# 526.)  Predicted: 221.03 	 Actual: 281.00
# 527.)  Predicted: 211.26 	 Actual: 280.00
# 528.)  Predicted: 242.02 	 Actual: 279.00
# 529.)  Predicted: 240.26 	 Actual: 278.00
# 530.)  Predicted: 232.85 	 Actual: 277.00
# 531.)  Predicted: 227.09 	 Actual: 276.00
# 532.)  Predicted: 233.43 	 Actual: 275.00
# 533.)  Predicted: 234.52 	 Actual: 274.00
# 534.)  Predicted: 230.78 	 Actual: 273.00
# 535.)  Predicted: 225.67 	 Actual: 272.00
# 536.)  Predicted: 237.78 	 Actual: 271.00
# 537.)  Predicted: 259.39 	 Actual: 270.00
# 538.)  Predicted: 229.30 	 Actual: 269.00
# 539.)  Predicted: 239.25 	 Actual: 268.00
# 540.)  Predicted: 232.38 	 Actual: 267.00
# 541.)  Predicted: 235.55 	 Actual: 266.00
# 542.)  Predicted: 253.25 	 Actual: 265.00
# 543.)  Predicted: 228.22 	 Actual: 264.00
# 544.)  Predicted: 222.11 	 Actual: 263.00
# 545.)  Predicted: 225.19 	 Actual: 262.00
# 546.)  Predicted: 224.51 	 Actual: 261.00
# 547.)  Predicted: 202.57 	 Actual: 260.00
# 548.)  Predicted: 210.86 	 Actual: 259.00
# 549.)  Predicted: 228.88 	 Actual: 258.00
# 550.)  Predicted: 231.71 	 Actual: 257.00
# 551.)  Predicted: 259.82 	 Actual: 256.00
# 552.)  Predicted: 180.60 	 Actual: 255.00
# 553.)  Predicted: 216.14 	 Actual: 254.00
# 554.)  Predicted: 246.29 	 Actual: 253.00
# 555.)  Predicted: 243.01 	 Actual: 252.00
# 556.)  Predicted: 220.56 	 Actual: 251.00
# 557.)  Predicted: 253.35 	 Actual: 250.00
# 558.)  Predicted: 213.29 	 Actual: 249.00
# 559.)  Predicted: 214.90 	 Actual: 248.00
# 560.)  Predicted: 228.17 	 Actual: 247.00
# 561.)  Predicted: 251.43 	 Actual: 246.00
# 562.)  Predicted: 214.72 	 Actual: 245.00
# 563.)  Predicted: 232.76 	 Actual: 244.00
# 564.)  Predicted: 215.62 	 Actual: 243.00
# 565.)  Predicted: 231.35 	 Actual: 242.00
# 566.)  Predicted: 242.93 	 Actual: 241.00
# 567.)  Predicted: 240.83 	 Actual: 240.00
# 568.)  Predicted: 245.22 	 Actual: 239.00
# 569.)  Predicted: 223.62 	 Actual: 238.00
# 570.)  Predicted: 214.00 	 Actual: 237.00
# 571.)  Predicted: 229.69 	 Actual: 236.00
# 572.)  Predicted: 229.31 	 Actual: 235.00
# 573.)  Predicted: 228.62 	 Actual: 234.00
# 574.)  Predicted: 223.54 	 Actual: 233.00
# 575.)  Predicted: 220.55 	 Actual: 232.00
# 576.)  Predicted: 233.74 	 Actual: 231.00
# 577.)  Predicted: 239.57 	 Actual: 230.00
# 578.)  Predicted: 257.79 	 Actual: 229.00
# 579.)  Predicted: 230.68 	 Actual: 228.00
# 580.)  Predicted: 217.13 	 Actual: 227.00
# 581.)  Predicted: 242.50 	 Actual: 226.00
# 582.)  Predicted: 220.95 	 Actual: 225.00
# 583.)  Predicted: 247.55 	 Actual: 224.00
# 584.)  Predicted: 214.90 	 Actual: 223.00
# 585.)  Predicted: 239.28 	 Actual: 222.00
# 586.)  Predicted: 229.37 	 Actual: 221.00
# 587.)  Predicted: 243.23 	 Actual: 220.00
# 588.)  Predicted: 236.15 	 Actual: 219.00
# 589.)  Predicted: 207.88 	 Actual: 218.00
# 590.)  Predicted: 222.92 	 Actual: 217.00
# 591.)  Predicted: 230.97 	 Actual: 216.00
# 592.)  Predicted: 235.91 	 Actual: 215.00
# 593.)  Predicted: 242.38 	 Actual: 214.00
# 594.)  Predicted: 218.94 	 Actual: 213.00
# 595.)  Predicted: 244.22 	 Actual: 212.00
# 596.)  Predicted: 213.25 	 Actual: 211.00
# 597.)  Predicted: 219.73 	 Actual: 210.00
# 598.)  Predicted: 221.07 	 Actual: 209.00
# 599.)  Predicted: 178.50 	 Actual: 208.00
# 600.)  Predicted: 229.38 	 Actual: 207.00
# 601.)  Predicted: 199.99 	 Actual: 206.00
# 602.)  Predicted: 237.01 	 Actual: 205.00
# 603.)  Predicted: 210.91 	 Actual: 204.00
# 604.)  Predicted: 225.30 	 Actual: 203.00
# 605.)  Predicted: 230.80 	 Actual: 202.00
# 606.)  Predicted: 250.11 	 Actual: 201.00
# 607.)  Predicted: 233.90 	 Actual: 200.00
# 608.)  Predicted: 210.04 	 Actual: 199.00
# 609.)  Predicted: 233.74 	 Actual: 198.00
# 610.)  Predicted: 225.10 	 Actual: 197.00
# 611.)  Predicted: 216.28 	 Actual: 196.00
# 612.)  Predicted: 222.41 	 Actual: 195.00
# 613.)  Predicted: 227.44 	 Actual: 194.00
# 614.)  Predicted: 220.57 	 Actual: 193.00
# 615.)  Predicted: 226.54 	 Actual: 192.00
# 616.)  Predicted: 251.09 	 Actual: 191.00
# 617.)  Predicted: 221.55 	 Actual: 190.00
# 618.)  Predicted: 222.26 	 Actual: 189.00
# 619.)  Predicted: 229.61 	 Actual: 188.00
# 620.)  Predicted: 246.30 	 Actual: 187.00
# 621.)  Predicted: 223.30 	 Actual: 186.00
# 622.)  Predicted: 236.05 	 Actual: 185.00
# 623.)  Predicted: 217.57 	 Actual: 184.00
# 624.)  Predicted: 251.13 	 Actual: 183.00
# 625.)  Predicted: 211.17 	 Actual: 182.00
# 626.)  Predicted: 234.98 	 Actual: 181.00
# 627.)  Predicted: 219.92 	 Actual: 180.00
# 628.)  Predicted: 216.83 	 Actual: 179.00
# 629.)  Predicted: 224.80 	 Actual: 178.00
# 630.)  Predicted: 200.78 	 Actual: 177.00
# 631.)  Predicted: 215.64 	 Actual: 176.00
# 632.)  Predicted: 226.59 	 Actual: 175.00
# 633.)  Predicted: 220.33 	 Actual: 174.00
# 634.)  Predicted: 227.52 	 Actual: 173.00
# 635.)  Predicted: 224.61 	 Actual: 172.00
# 636.)  Predicted: 213.55 	 Actual: 171.00
# 637.)  Predicted: 194.06 	 Actual: 170.00
# 638.)  Predicted: 217.50 	 Actual: 169.00
# 639.)  Predicted: 224.20 	 Actual: 168.00
# 640.)  Predicted: 224.20 	 Actual: 167.00
# 641.)  Predicted: 220.44 	 Actual: 166.00
# 642.)  Predicted: 218.40 	 Actual: 165.00
# 643.)  Predicted: 216.94 	 Actual: 164.00
# 644.)  Predicted: 224.35 	 Actual: 163.00
# 645.)  Predicted: 236.82 	 Actual: 162.00
# 646.)  Predicted: 222.41 	 Actual: 161.00
# 647.)  Predicted: 193.61 	 Actual: 160.00
# 648.)  Predicted: 233.77 	 Actual: 159.00
# 649.)  Predicted: 203.31 	 Actual: 158.00
# 650.)  Predicted: 192.63 	 Actual: 157.00
# 651.)  Predicted: 235.65 	 Actual: 156.00
# 652.)  Predicted: 224.10 	 Actual: 155.00
# 653.)  Predicted: 221.75 	 Actual: 154.00
# 654.)  Predicted: 207.62 	 Actual: 153.00
# 655.)  Predicted: 233.16 	 Actual: 152.00
# 656.)  Predicted: 211.89 	 Actual: 151.00
# 657.)  Predicted: 206.01 	 Actual: 150.00
# 658.)  Predicted: 214.63 	 Actual: 149.00
# 659.)  Predicted: 224.22 	 Actual: 148.00
# 660.)  Predicted: 232.31 	 Actual: 147.00
# 661.)  Predicted: 227.96 	 Actual: 146.00
# 662.)  Predicted: 199.34 	 Actual: 145.00
# 663.)  Predicted: 203.10 	 Actual: 144.00
# 664.)  Predicted: 215.10 	 Actual: 143.00
# 665.)  Predicted: 199.88 	 Actual: 142.00
# 666.)  Predicted: 235.38 	 Actual: 141.00
# 667.)  Predicted: 210.15 	 Actual: 140.00
# 668.)  Predicted: 208.60 	 Actual: 139.00
# 669.)  Predicted: 225.71 	 Actual: 138.00
# 670.)  Predicted: 218.82 	 Actual: 137.00
# 671.)  Predicted: 221.26 	 Actual: 136.00
# 672.)  Predicted: 217.02 	 Actual: 135.00
# 673.)  Predicted: 222.85 	 Actual: 134.00
# 674.)  Predicted: 230.92 	 Actual: 133.00
# 675.)  Predicted: 226.97 	 Actual: 132.00
# 676.)  Predicted: 226.12 	 Actual: 131.00
# 677.)  Predicted: 224.65 	 Actual: 130.00
# 678.)  Predicted: 205.01 	 Actual: 129.00
# 679.)  Predicted: 220.46 	 Actual: 128.00
# 680.)  Predicted: 220.54 	 Actual: 127.00
# 681.)  Predicted: 205.97 	 Actual: 126.00
# 682.)  Predicted: 187.06 	 Actual: 125.00
# 683.)  Predicted: 201.25 	 Actual: 124.00
# 684.)  Predicted: 198.61 	 Actual: 123.00
# 685.)  Predicted: 226.72 	 Actual: 122.00
# 686.)  Predicted: 191.53 	 Actual: 121.00
# 687.)  Predicted: 197.86 	 Actual: 120.00
# 688.)  Predicted: 216.55 	 Actual: 119.00
# 689.)  Predicted: 236.92 	 Actual: 118.00
# 690.)  Predicted: 220.09 	 Actual: 117.00
# 691.)  Predicted: 211.85 	 Actual: 116.00
# 692.)  Predicted: 213.15 	 Actual: 115.00
# 693.)  Predicted: 192.82 	 Actual: 114.00
# 694.)  Predicted: 213.27 	 Actual: 113.00
# 695.)  Predicted: 203.85 	 Actual: 112.00
# 696.)  Predicted: 199.60 	 Actual: 111.00
# 697.)  Predicted: 209.74 	 Actual: 110.00
# 698.)  Predicted: 195.25 	 Actual: 109.00
# 699.)  Predicted: 189.96 	 Actual: 108.00
# 700.)  Predicted: 199.26 	 Actual: 107.00
# 701.)  Predicted: 205.07 	 Actual: 106.00
# 702.)  Predicted: 223.28 	 Actual: 105.00
# 703.)  Predicted: 192.52 	 Actual: 104.00
# 704.)  Predicted: 224.55 	 Actual: 103.00
# 705.)  Predicted: 183.92 	 Actual: 102.00
# 706.)  Predicted: 224.14 	 Actual: 101.00
# 707.)  Predicted: 152.60 	 Actual: 100.00
# 708.)  Predicted: 214.24 	 Actual: 99.00
# 709.)  Predicted: 157.55 	 Actual: 98.00
# 710.)  Predicted: 205.21 	 Actual: 97.00
# 711.)  Predicted: 191.79 	 Actual: 96.00
# 712.)  Predicted: 206.49 	 Actual: 95.00
# 713.)  Predicted: 185.76 	 Actual: 94.00
# 714.)  Predicted: 203.47 	 Actual: 93.00
# 715.)  Predicted: 170.31 	 Actual: 92.00
# 716.)  Predicted: 184.94 	 Actual: 91.00
# 717.)  Predicted: 202.87 	 Actual: 90.00
# 718.)  Predicted: 158.14 	 Actual: 89.00
# 719.)  Predicted: 183.63 	 Actual: 88.00
# 720.)  Predicted: 200.86 	 Actual: 87.00
# 721.)  Predicted: 189.36 	 Actual: 86.00
# 722.)  Predicted: 174.72 	 Actual: 85.00
# 723.)  Predicted: 173.73 	 Actual: 84.00
# 724.)  Predicted: 151.93 	 Actual: 83.00
# 725.)  Predicted: 183.40 	 Actual: 82.00
# 726.)  Predicted: 171.66 	 Actual: 81.00
# 727.)  Predicted: 169.36 	 Actual: 80.00
# 728.)  Predicted: 194.69 	 Actual: 79.00
# 729.)  Predicted: 174.85 	 Actual: 78.00
# 730.)  Predicted: 187.70 	 Actual: 77.00
# 731.)  Predicted: 196.76 	 Actual: 76.00
# 732.)  Predicted: 175.42 	 Actual: 75.00
# 733.)  Predicted: 112.93 	 Actual: 199.00
# 734.)  Predicted: 89.04 	 Actual: 198.00
# 735.)  Predicted: 92.57 	 Actual: 197.00
# 736.)  Predicted: 89.54 	 Actual: 196.00
# 737.)  Predicted: 63.74 	 Actual: 195.00
# 738.)  Predicted: 119.91 	 Actual: 194.00
# 739.)  Predicted: 82.93 	 Actual: 193.00
# 740.)  Predicted: 92.72 	 Actual: 192.00
# 741.)  Predicted: 62.40 	 Actual: 191.00
# 742.)  Predicted: 104.63 	 Actual: 190.00
# 743.)  Predicted: 75.52 	 Actual: 189.00
# 744.)  Predicted: 116.52 	 Actual: 188.00
# 745.)  Predicted: 126.46 	 Actual: 187.00
# 746.)  Predicted: 96.77 	 Actual: 186.00
# 747.)  Predicted: 72.78 	 Actual: 185.00
# 748.)  Predicted: 86.49 	 Actual: 184.00
# 749.)  Predicted: 111.77 	 Actual: 183.00
# 750.)  Predicted: 76.10 	 Actual: 182.00
# 751.)  Predicted: 93.39 	 Actual: 181.00
# 752.)  Predicted: 118.90 	 Actual: 180.00
# 753.)  Predicted: 99.51 	 Actual: 179.00
# 754.)  Predicted: 110.04 	 Actual: 178.00
# 755.)  Predicted: 99.28 	 Actual: 177.00
# 756.)  Predicted: 116.08 	 Actual: 176.00
# 757.)  Predicted: 94.50 	 Actual: 175.00
# 758.)  Predicted: 98.12 	 Actual: 174.00
# 759.)  Predicted: 91.78 	 Actual: 173.00
# 760.)  Predicted: 117.75 	 Actual: 172.00
# 761.)  Predicted: 67.70 	 Actual: 171.00
# 762.)  Predicted: 78.73 	 Actual: 170.00
# 763.)  Predicted: 146.67 	 Actual: 169.00
# 764.)  Predicted: 49.98 	 Actual: 168.00
# 765.)  Predicted: 78.98 	 Actual: 167.00
# 766.)  Predicted: 69.81 	 Actual: 166.00
# 767.)  Predicted: 79.24 	 Actual: 165.00
# 768.)  Predicted: 115.42 	 Actual: 164.00
# 769.)  Predicted: 120.57 	 Actual: 163.00
# 770.)  Predicted: 80.29 	 Actual: 162.00
# 771.)  Predicted: 61.35 	 Actual: 161.00
# 772.)  Predicted: 109.45 	 Actual: 160.00
# 773.)  Predicted: 90.49 	 Actual: 159.00
# 774.)  Predicted: 104.25 	 Actual: 158.00
# 775.)  Predicted: 116.55 	 Actual: 157.00
# 776.)  Predicted: 93.64 	 Actual: 156.00
# 777.)  Predicted: 92.63 	 Actual: 155.00
# 778.)  Predicted: 85.12 	 Actual: 154.00
# 779.)  Predicted: 89.66 	 Actual: 153.00
# 780.)  Predicted: 100.24 	 Actual: 152.00
# 781.)  Predicted: 75.75 	 Actual: 151.00
# 782.)  Predicted: 86.48 	 Actual: 150.00
# 783.)  Predicted: 70.00 	 Actual: 149.00
# 784.)  Predicted: 202.80 	 Actual: 223.00
# 785.)  Predicted: 218.20 	 Actual: 222.00
# 786.)  Predicted: 239.07 	 Actual: 221.00
# 787.)  Predicted: 233.70 	 Actual: 220.00
# 788.)  Predicted: 198.42 	 Actual: 219.00
# 789.)  Predicted: 229.12 	 Actual: 218.00
# 790.)  Predicted: 215.11 	 Actual: 217.00
# 791.)  Predicted: 205.34 	 Actual: 216.00
# 792.)  Predicted: 224.99 	 Actual: 215.00
# 793.)  Predicted: 221.60 	 Actual: 214.00
# 794.)  Predicted: 214.18 	 Actual: 213.00
# 795.)  Predicted: 207.99 	 Actual: 212.00
# 796.)  Predicted: 214.68 	 Actual: 211.00
# 797.)  Predicted: 215.06 	 Actual: 210.00
# 798.)  Predicted: 211.89 	 Actual: 209.00
# 799.)  Predicted: 195.67 	 Actual: 208.00
# 800.)  Predicted: 210.67 	 Actual: 207.00
# 801.)  Predicted: 196.09 	 Actual: 206.00
# 802.)  Predicted: 226.51 	 Actual: 205.00
# 803.)  Predicted: 213.07 	 Actual: 204.00
# 804.)  Predicted: 216.35 	 Actual: 203.00
# 805.)  Predicted: 202.94 	 Actual: 202.00
# 806.)  Predicted: 208.83 	 Actual: 201.00
# 807.)  Predicted: 211.67 	 Actual: 200.00
# 808.)  Predicted: 192.94 	 Actual: 199.00
# 809.)  Predicted: 198.71 	 Actual: 198.00
# 810.)  Predicted: 218.42 	 Actual: 197.00
# 811.)  Predicted: 202.49 	 Actual: 196.00
# 812.)  Predicted: 224.46 	 Actual: 195.00
# 813.)  Predicted: 200.71 	 Actual: 194.00
# 814.)  Predicted: 227.99 	 Actual: 193.00
# 815.)  Predicted: 231.41 	 Actual: 192.00
# 816.)  Predicted: 204.57 	 Actual: 191.00
# 817.)  Predicted: 225.93 	 Actual: 190.00
# 818.)  Predicted: 206.28 	 Actual: 189.00
# 819.)  Predicted: 202.96 	 Actual: 188.00
# 820.)  Predicted: 210.63 	 Actual: 187.00
# 821.)  Predicted: 217.23 	 Actual: 186.00
# 822.)  Predicted: 193.16 	 Actual: 185.00
# 823.)  Predicted: 230.59 	 Actual: 184.00
# 824.)  Predicted: 216.45 	 Actual: 183.00
# 825.)  Predicted: 228.45 	 Actual: 182.00
# 826.)  Predicted: 210.47 	 Actual: 181.00
# 827.)  Predicted: 204.16 	 Actual: 180.00
# 828.)  Predicted: 217.48 	 Actual: 179.00
# 829.)  Predicted: 209.24 	 Actual: 178.00
# 830.)  Predicted: 199.19 	 Actual: 177.00
# 831.)  Predicted: 201.05 	 Actual: 176.00
# 832.)  Predicted: 213.99 	 Actual: 175.00
# 833.)  Predicted: 213.32 	 Actual: 174.00
# 834.)  Predicted: 201.30 	 Actual: 173.00
# 835.)  Predicted: 219.93 	 Actual: 172.00
# 836.)  Predicted: 199.26 	 Actual: 171.00
# 837.)  Predicted: 206.66 	 Actual: 170.00
# 838.)  Predicted: 216.53 	 Actual: 169.00
# 839.)  Predicted: 208.78 	 Actual: 168.00
# 840.)  Predicted: 198.35 	 Actual: 167.00
# 841.)  Predicted: 214.69 	 Actual: 166.00
# 842.)  Predicted: 198.66 	 Actual: 165.00
# 843.)  Predicted: 216.85 	 Actual: 164.00
# 844.)  Predicted: 204.60 	 Actual: 163.00
# 845.)  Predicted: 210.74 	 Actual: 162.00
# 846.)  Predicted: 198.28 	 Actual: 161.00
# 847.)  Predicted: 188.32 	 Actual: 160.00
# 848.)  Predicted: 173.64 	 Actual: 159.00
# 849.)  Predicted: 236.68 	 Actual: 158.00
# 850.)  Predicted: 203.41 	 Actual: 157.00
# 851.)  Predicted: 209.51 	 Actual: 156.00
# 852.)  Predicted: 208.27 	 Actual: 155.00
# 853.)  Predicted: 194.76 	 Actual: 154.00
# 854.)  Predicted: 233.51 	 Actual: 153.00
# 855.)  Predicted: 220.53 	 Actual: 152.00
# 856.)  Predicted: 210.80 	 Actual: 151.00
# 857.)  Predicted: 206.99 	 Actual: 150.00
# 858.)  Predicted: 201.76 	 Actual: 149.00
# 859.)  Predicted: 214.36 	 Actual: 148.00
# 860.)  Predicted: 201.97 	 Actual: 147.00
# 861.)  Predicted: 222.46 	 Actual: 146.00
# 862.)  Predicted: 196.88 	 Actual: 145.00
# 863.)  Predicted: 176.83 	 Actual: 144.00
# 864.)  Predicted: 199.04 	 Actual: 143.00
# 865.)  Predicted: 224.75 	 Actual: 142.00
# 866.)  Predicted: 177.00 	 Actual: 141.00
# 867.)  Predicted: 179.72 	 Actual: 140.00
# 868.)  Predicted: 225.42 	 Actual: 139.00
# 869.)  Predicted: 190.49 	 Actual: 138.00
# 870.)  Predicted: 215.51 	 Actual: 137.00
# 871.)  Predicted: 203.72 	 Actual: 136.00
# 872.)  Predicted: 182.87 	 Actual: 135.00
# 873.)  Predicted: 200.72 	 Actual: 134.00
# 874.)  Predicted: 214.95 	 Actual: 133.00
# 875.)  Predicted: 206.28 	 Actual: 132.00
# 876.)  Predicted: 194.43 	 Actual: 131.00
# 877.)  Predicted: 201.01 	 Actual: 130.00
# 878.)  Predicted: 175.87 	 Actual: 129.00
# 879.)  Predicted: 181.72 	 Actual: 128.00
# 880.)  Predicted: 178.92 	 Actual: 127.00
# 881.)  Predicted: 221.68 	 Actual: 126.00
# 882.)  Predicted: 187.59 	 Actual: 125.00
# 883.)  Predicted: 232.31 	 Actual: 124.00
# 884.)  Predicted: 189.26 	 Actual: 123.00
# 885.)  Predicted: 174.56 	 Actual: 122.00
# 886.)  Predicted: 183.23 	 Actual: 121.00
# 887.)  Predicted: 200.21 	 Actual: 120.00
# 888.)  Predicted: 199.73 	 Actual: 119.00
# 889.)  Predicted: 202.80 	 Actual: 118.00
# 890.)  Predicted: 186.13 	 Actual: 117.00
# 891.)  Predicted: 198.56 	 Actual: 116.00
# 892.)  Predicted: 208.91 	 Actual: 115.00
# 893.)  Predicted: 196.13 	 Actual: 114.00
# 894.)  Predicted: 200.30 	 Actual: 113.00
# 895.)  Predicted: 193.67 	 Actual: 112.00
# 896.)  Predicted: 179.16 	 Actual: 111.00
# 897.)  Predicted: 181.89 	 Actual: 110.00
# 898.)  Predicted: 184.80 	 Actual: 109.00
# 899.)  Predicted: 201.95 	 Actual: 108.00
# 900.)  Predicted: 165.16 	 Actual: 107.00
# 901.)  Predicted: 183.97 	 Actual: 106.00
# 902.)  Predicted: 203.80 	 Actual: 105.00
# 903.)  Predicted: 211.38 	 Actual: 104.00
# 904.)  Predicted: 174.38 	 Actual: 103.00
# 905.)  Predicted: 176.56 	 Actual: 102.00
# 906.)  Predicted: 191.82 	 Actual: 101.00
# 907.)  Predicted: 175.99 	 Actual: 100.00
# 908.)  Predicted: 191.53 	 Actual: 99.00
# 909.)  Predicted: 174.22 	 Actual: 98.00
# 910.)  Predicted: 201.63 	 Actual: 97.00
# 911.)  Predicted: 183.43 	 Actual: 96.00
# 912.)  Predicted: 181.75 	 Actual: 95.00
# 913.)  Predicted: 214.84 	 Actual: 94.00
# 914.)  Predicted: 165.88 	 Actual: 93.00
# 915.)  Predicted: 174.33 	 Actual: 92.00
# 916.)  Predicted: 188.08 	 Actual: 91.00
# 917.)  Predicted: 161.96 	 Actual: 90.00
# 918.)  Predicted: 192.92 	 Actual: 89.00
# 919.)  Predicted: 170.15 	 Actual: 88.00
# 920.)  Predicted: 191.43 	 Actual: 87.00
# 921.)  Predicted: 185.90 	 Actual: 86.00
# 922.)  Predicted: 173.78 	 Actual: 85.00
# 923.)  Predicted: 167.65 	 Actual: 84.00
# 924.)  Predicted: 199.33 	 Actual: 83.00
# 925.)  Predicted: 172.90 	 Actual: 82.00
# 926.)  Predicted: 183.91 	 Actual: 81.00
# 927.)  Predicted: 158.91 	 Actual: 80.00
# 928.)  Predicted: 176.24 	 Actual: 79.00
# 929.)  Predicted: 152.31 	 Actual: 78.00
# 930.)  Predicted: 107.34 	 Actual: 147.00
# 931.)  Predicted: 122.27 	 Actual: 146.00
# 932.)  Predicted: 94.28 	 Actual: 145.00
# 933.)  Predicted: 123.42 	 Actual: 144.00
# 934.)  Predicted: 105.67 	 Actual: 143.00
# 935.)  Predicted: 96.36 	 Actual: 142.00
# 936.)  Predicted: 95.90 	 Actual: 141.00
# 937.)  Predicted: 78.94 	 Actual: 140.00
# 938.)  Predicted: 52.75 	 Actual: 139.00
# 939.)  Predicted: 126.43 	 Actual: 138.00
# 940.)  Predicted: 84.62 	 Actual: 137.00
# 941.)  Predicted: 99.65 	 Actual: 136.00
# 942.)  Predicted: 100.68 	 Actual: 135.00
# 943.)  Predicted: 95.92 	 Actual: 134.00
# 944.)  Predicted: 98.13 	 Actual: 133.00
# 945.)  Predicted: 88.77 	 Actual: 132.00
# 946.)  Predicted: 79.94 	 Actual: 131.00
# 947.)  Predicted: 98.28 	 Actual: 130.00
# 948.)  Predicted: 90.16 	 Actual: 129.00
# 949.)  Predicted: 47.69 	 Actual: 128.00
# 950.)  Predicted: 91.65 	 Actual: 127.00
# 951.)  Predicted: 102.76 	 Actual: 126.00
# 952.)  Predicted: 74.02 	 Actual: 125.00
# 953.)  Predicted: 101.19 	 Actual: 124.00
# 954.)  Predicted: 87.47 	 Actual: 123.00
# 955.)  Predicted: 83.87 	 Actual: 122.00
# 956.)  Predicted: 87.91 	 Actual: 121.00
# 957.)  Predicted: 91.46 	 Actual: 120.00
# 958.)  Predicted: 95.81 	 Actual: 119.00
# 959.)  Predicted: 126.25 	 Actual: 118.00
# 960.)  Predicted: 60.41 	 Actual: 117.00
# 961.)  Predicted: 106.99 	 Actual: 116.00
# 962.)  Predicted: 116.25 	 Actual: 115.00
# 963.)  Predicted: 73.73 	 Actual: 114.00
# 964.)  Predicted: 101.80 	 Actual: 113.00
# 965.)  Predicted: 122.72 	 Actual: 112.00
# 966.)  Predicted: 92.73 	 Actual: 111.00
# 967.)  Predicted: 97.38 	 Actual: 110.00
# 968.)  Predicted: 82.04 	 Actual: 109.00
# 969.)  Predicted: 72.57 	 Actual: 108.00
# 970.)  Predicted: 53.51 	 Actual: 107.00
# 971.)  Predicted: 119.42 	 Actual: 106.00
# 972.)  Predicted: 111.43 	 Actual: 105.00
# 973.)  Predicted: 108.10 	 Actual: 104.00
# 974.)  Predicted: 73.50 	 Actual: 103.00
# 975.)  Predicted: 90.63 	 Actual: 102.00
# 976.)  Predicted: 117.18 	 Actual: 101.00
# 977.)  Predicted: 89.44 	 Actual: 100.00
# 978.)  Predicted: 85.27 	 Actual: 99.00
# 979.)  Predicted: 65.49 	 Actual: 98.00
# 980.)  Predicted: 126.32 	 Actual: 97.00
# 981.)  Predicted: 120.29 	 Actual: 96.00
# 982.)  Predicted: 71.20 	 Actual: 95.00
# 983.)  Predicted: 94.87 	 Actual: 94.00
# 984.)  Predicted: 166.44 	 Actual: 261.00
# 985.)  Predicted: 160.16 	 Actual: 260.00
# 986.)  Predicted: 160.10 	 Actual: 259.00
# 987.)  Predicted: 163.49 	 Actual: 258.00
# 988.)  Predicted: 164.10 	 Actual: 257.00
# 989.)  Predicted: 142.03 	 Actual: 256.00
# 990.)  Predicted: 142.83 	 Actual: 255.00
# 991.)  Predicted: 160.31 	 Actual: 254.00
# 992.)  Predicted: 142.73 	 Actual: 253.00
# 993.)  Predicted: 114.19 	 Actual: 252.00
# 994.)  Predicted: 155.44 	 Actual: 251.00
# 995.)  Predicted: 131.63 	 Actual: 250.00
# 996.)  Predicted: 159.78 	 Actual: 249.00
# 997.)  Predicted: 152.83 	 Actual: 248.00
# 998.)  Predicted: 173.17 	 Actual: 247.00
# 999.)  Predicted: 147.65 	 Actual: 246.00
# 1000.)  Predicted: 123.12 	 Actual: 245.00
# 1001.)  Predicted: 151.66 	 Actual: 244.00
# 1002.)  Predicted: 150.51 	 Actual: 243.00
# 1003.)  Predicted: 140.09 	 Actual: 242.00
# 1004.)  Predicted: 173.05 	 Actual: 241.00
# 1005.)  Predicted: 183.11 	 Actual: 240.00
# 1006.)  Predicted: 136.18 	 Actual: 239.00
# 1007.)  Predicted: 123.11 	 Actual: 238.00
# 1008.)  Predicted: 145.39 	 Actual: 237.00
# 1009.)  Predicted: 105.22 	 Actual: 236.00
# 1010.)  Predicted: 167.11 	 Actual: 235.00
# 1011.)  Predicted: 163.77 	 Actual: 234.00
# 1012.)  Predicted: 168.03 	 Actual: 233.00
# 1013.)  Predicted: 147.48 	 Actual: 232.00
# 1014.)  Predicted: 149.13 	 Actual: 231.00
# 1015.)  Predicted: 179.21 	 Actual: 230.00
# 1016.)  Predicted: 135.82 	 Actual: 229.00
# 1017.)  Predicted: 149.51 	 Actual: 228.00
# 1018.)  Predicted: 127.44 	 Actual: 227.00
# 1019.)  Predicted: 173.06 	 Actual: 226.00
# 1020.)  Predicted: 117.98 	 Actual: 225.00
# 1021.)  Predicted: 128.63 	 Actual: 224.00
# 1022.)  Predicted: 165.60 	 Actual: 223.00
# 1023.)  Predicted: 132.32 	 Actual: 222.00
# 1024.)  Predicted: 157.83 	 Actual: 221.00
# 1025.)  Predicted: 145.57 	 Actual: 220.00
# 1026.)  Predicted: 144.70 	 Actual: 219.00
# 1027.)  Predicted: 170.50 	 Actual: 218.00
# 1028.)  Predicted: 172.19 	 Actual: 217.00
# 1029.)  Predicted: 174.11 	 Actual: 216.00
# 1030.)  Predicted: 164.03 	 Actual: 215.00
# 1031.)  Predicted: 165.42 	 Actual: 214.00
# 1032.)  Predicted: 147.84 	 Actual: 213.00
# 1033.)  Predicted: 148.35 	 Actual: 212.00
# 1034.)  Predicted: 137.52 	 Actual: 211.00
# 1035.)  Predicted: 124.58 	 Actual: 210.00
# 1036.)  Predicted: 151.90 	 Actual: 209.00
# 1037.)  Predicted: 154.15 	 Actual: 208.00
# 1038.)  Predicted: 130.80 	 Actual: 207.00
# 1039.)  Predicted: 172.81 	 Actual: 206.00
# 1040.)  Predicted: 144.11 	 Actual: 205.00
# 1041.)  Predicted: 131.53 	 Actual: 204.00
# 1042.)  Predicted: 140.83 	 Actual: 203.00
# 1043.)  Predicted: 155.17 	 Actual: 202.00
# 1044.)  Predicted: 145.83 	 Actual: 201.00
# 1045.)  Predicted: 128.89 	 Actual: 200.00
# 1046.)  Predicted: 141.81 	 Actual: 199.00
# 1047.)  Predicted: 140.82 	 Actual: 198.00
# 1048.)  Predicted: 104.08 	 Actual: 197.00
# 1049.)  Predicted: 139.62 	 Actual: 196.00
# 1050.)  Predicted: 135.31 	 Actual: 195.00
# 1051.)  Predicted: 142.20 	 Actual: 194.00
# 1052.)  Predicted: 137.91 	 Actual: 193.00
# 1053.)  Predicted: 126.00 	 Actual: 192.00
# 1054.)  Predicted: 143.86 	 Actual: 191.00
# 1055.)  Predicted: 168.91 	 Actual: 190.00
# 1056.)  Predicted: 161.16 	 Actual: 189.00
# 1057.)  Predicted: 138.33 	 Actual: 188.00
# 1058.)  Predicted: 130.01 	 Actual: 187.00
# 1059.)  Predicted: 148.83 	 Actual: 186.00
# 1060.)  Predicted: 137.32 	 Actual: 185.00
# 1061.)  Predicted: 150.08 	 Actual: 184.00
# 1062.)  Predicted: 108.08 	 Actual: 183.00
# 1063.)  Predicted: 170.36 	 Actual: 182.00
# 1064.)  Predicted: 125.29 	 Actual: 181.00
# 1065.)  Predicted: 136.17 	 Actual: 180.00
# 1066.)  Predicted: 168.30 	 Actual: 179.00
# 1067.)  Predicted: 127.13 	 Actual: 178.00
# 1068.)  Predicted: 174.33 	 Actual: 177.00
# 1069.)  Predicted: 131.04 	 Actual: 176.00
# 1070.)  Predicted: 118.88 	 Actual: 175.00
# 1071.)  Predicted: 124.67 	 Actual: 174.00
# 1072.)  Predicted: 164.20 	 Actual: 173.00
# 1073.)  Predicted: 155.77 	 Actual: 172.00
# 1074.)  Predicted: 118.45 	 Actual: 171.00
# 1075.)  Predicted: 111.88 	 Actual: 170.00
# 1076.)  Predicted: 124.45 	 Actual: 169.00
# 1077.)  Predicted: 98.85 	 Actual: 168.00
# 1078.)  Predicted: 149.78 	 Actual: 167.00
# 1079.)  Predicted: 122.32 	 Actual: 166.00
# 1080.)  Predicted: 127.18 	 Actual: 165.00
# 1081.)  Predicted: 124.60 	 Actual: 164.00
# 1082.)  Predicted: 141.75 	 Actual: 163.00
# 1083.)  Predicted: 116.52 	 Actual: 162.00
# 1084.)  Predicted: 93.23 	 Actual: 161.00
# 1085.)  Predicted: 142.98 	 Actual: 160.00
# 1086.)  Predicted: 144.96 	 Actual: 159.00
# 1087.)  Predicted: 130.52 	 Actual: 158.00
# 1088.)  Predicted: 110.21 	 Actual: 157.00
# 1089.)  Predicted: 140.11 	 Actual: 156.00
# 1090.)  Predicted: 97.49 	 Actual: 155.00
# 1091.)  Predicted: 172.87 	 Actual: 154.00
# 1092.)  Predicted: 134.14 	 Actual: 153.00
# 1093.)  Predicted: 136.47 	 Actual: 152.00
# 1094.)  Predicted: 141.71 	 Actual: 151.00
# 1095.)  Predicted: 117.83 	 Actual: 150.00
# 1096.)  Predicted: 98.20 	 Actual: 149.00
# 1097.)  Predicted: 111.10 	 Actual: 148.00
# 1098.)  Predicted: 144.81 	 Actual: 147.00
# 1099.)  Predicted: 125.88 	 Actual: 146.00
# 1100.)  Predicted: 158.74 	 Actual: 145.00
# 1101.)  Predicted: 133.42 	 Actual: 144.00
# 1102.)  Predicted: 136.19 	 Actual: 143.00
# 1103.)  Predicted: 112.43 	 Actual: 142.00
# 1104.)  Predicted: 155.21 	 Actual: 141.00
# 1105.)  Predicted: 95.14 	 Actual: 140.00
# 1106.)  Predicted: 112.63 	 Actual: 139.00
# 1107.)  Predicted: 121.36 	 Actual: 138.00
# 1108.)  Predicted: 161.34 	 Actual: 137.00
# 1109.)  Predicted: 89.07 	 Actual: 136.00
# 1110.)  Predicted: 135.63 	 Actual: 135.00
# 1111.)  Predicted: 110.68 	 Actual: 134.00
# 1112.)  Predicted: 116.10 	 Actual: 133.00
# 1113.)  Predicted: 102.06 	 Actual: 132.00
# 1114.)  Predicted: 144.58 	 Actual: 131.00
# 1115.)  Predicted: 124.86 	 Actual: 130.00
# 1116.)  Predicted: 110.01 	 Actual: 129.00
# 1117.)  Predicted: 101.35 	 Actual: 128.00
# 1118.)  Predicted: 116.73 	 Actual: 127.00
# 1119.)  Predicted: 92.78 	 Actual: 126.00
# 1120.)  Predicted: 110.94 	 Actual: 125.00
# 1121.)  Predicted: 115.50 	 Actual: 124.00
# 1122.)  Predicted: 61.51 	 Actual: 123.00
# 1123.)  Predicted: 145.40 	 Actual: 122.00
# 1124.)  Predicted: 102.17 	 Actual: 121.00
# 1125.)  Predicted: 102.61 	 Actual: 120.00
# 1126.)  Predicted: 114.14 	 Actual: 119.00
# 1127.)  Predicted: 100.25 	 Actual: 118.00
# 1128.)  Predicted: 112.76 	 Actual: 117.00
# 1129.)  Predicted: 101.98 	 Actual: 116.00
# 1130.)  Predicted: 128.06 	 Actual: 115.00
# 1131.)  Predicted: 94.79 	 Actual: 114.00
# 1132.)  Predicted: 64.70 	 Actual: 113.00
# 1133.)  Predicted: 101.40 	 Actual: 112.00
# 1134.)  Predicted: 89.29 	 Actual: 111.00
# 1135.)  Predicted: 107.24 	 Actual: 110.00
# 1136.)  Predicted: 93.97 	 Actual: 109.00
# 1137.)  Predicted: 93.56 	 Actual: 108.00
# 1138.)  Predicted: 96.95 	 Actual: 107.00
# 1139.)  Predicted: 85.56 	 Actual: 106.00
# 1140.)  Predicted: 86.25 	 Actual: 105.00
# 1141.)  Predicted: 31.85 	 Actual: 104.00
# 1142.)  Predicted: 109.03 	 Actual: 103.00
# 1143.)  Predicted: 100.12 	 Actual: 102.00
# 1144.)  Predicted: 95.21 	 Actual: 101.00
# 1145.)  Predicted: 87.31 	 Actual: 100.00
# 1146.)  Predicted: 98.32 	 Actual: 99.00
# 1147.)  Predicted: 81.11 	 Actual: 98.00
# 1148.)  Predicted: 67.38 	 Actual: 97.00
# 1149.)  Predicted: 69.40 	 Actual: 96.00
# ...
# 40848.)  Predicted: 124.19 	 Actual: 197.00
# 40849.)  Predicted: 101.64 	 Actual: 196.00
# 40850.)  Predicted: 118.72 	 Actual: 195.00
# 40851.)  Predicted: 126.07 	 Actual: 194.00
# 40852.)  Predicted: 124.80 	 Actual: 193.00
# 40853.)  Predicted: 130.03 	 Actual: 192.00
# 40854.)  Predicted: 104.89 	 Actual: 191.00
# 40855.)  Predicted: 110.20 	 Actual: 190.00
# 40856.)  Predicted: 136.14 	 Actual: 189.00
# 40857.)  Predicted: 130.33 	 Actual: 188.00
# 40858.)  Predicted: 100.46 	 Actual: 187.00
# 40859.)  Predicted: 138.90 	 Actual: 186.00
# 40860.)  Predicted: 108.47 	 Actual: 185.00
# 40861.)  Predicted: 103.14 	 Actual: 184.00
# 40862.)  Predicted: 83.11 	 Actual: 183.00
# 40863.)  Predicted: 133.56 	 Actual: 182.00
# 40864.)  Predicted: 107.87 	 Actual: 181.00
# 40865.)  Predicted: 114.85 	 Actual: 180.00
# 40866.)  Predicted: 117.74 	 Actual: 179.00
# 40867.)  Predicted: 99.11 	 Actual: 178.00
# 40868.)  Predicted: 106.65 	 Actual: 177.00
# 40869.)  Predicted: 133.48 	 Actual: 176.00
# 40870.)  Predicted: 133.80 	 Actual: 175.00
# 40871.)  Predicted: 108.04 	 Actual: 174.00
# 40872.)  Predicted: 114.56 	 Actual: 173.00
# 40873.)  Predicted: 98.15 	 Actual: 172.00
# 40874.)  Predicted: 83.76 	 Actual: 171.00
# 40875.)  Predicted: 114.71 	 Actual: 170.00
# 40876.)  Predicted: 115.91 	 Actual: 169.00
# 40877.)  Predicted: 117.97 	 Actual: 168.00
# 40878.)  Predicted: 146.11 	 Actual: 167.00
# 40879.)  Predicted: 99.60 	 Actual: 166.00
# 40880.)  Predicted: 127.45 	 Actual: 165.00
# 40881.)  Predicted: 100.81 	 Actual: 164.00
# 40882.)  Predicted: 112.04 	 Actual: 163.00
# 40883.)  Predicted: 109.51 	 Actual: 162.00
# 40884.)  Predicted: 126.45 	 Actual: 161.00
# 40885.)  Predicted: 100.27 	 Actual: 160.00
# 40886.)  Predicted: 101.19 	 Actual: 159.00
# 40887.)  Predicted: 58.12 	 Actual: 158.00
# 40888.)  Predicted: 96.28 	 Actual: 157.00
# 40889.)  Predicted: 117.01 	 Actual: 156.00
# 40890.)  Predicted: 99.14 	 Actual: 155.00
# 40891.)  Predicted: 67.84 	 Actual: 154.00
# 40892.)  Predicted: 127.39 	 Actual: 153.00
# 40893.)  Predicted: 74.92 	 Actual: 152.00
# 40894.)  Predicted: 137.73 	 Actual: 151.00
# 40895.)  Predicted: 122.73 	 Actual: 150.00
# 40896.)  Predicted: 141.58 	 Actual: 149.00
# 40897.)  Predicted: 137.95 	 Actual: 148.00
# 40898.)  Predicted: 48.11 	 Actual: 147.00
# 40899.)  Predicted: 115.53 	 Actual: 146.00
# 40900.)  Predicted: 70.78 	 Actual: 145.00
# 40901.)  Predicted: 129.87 	 Actual: 144.00
# 40902.)  Predicted: 128.91 	 Actual: 143.00
# 40903.)  Predicted: 117.97 	 Actual: 142.00
# 40904.)  Predicted: 91.08 	 Actual: 141.00
# 40905.)  Predicted: 95.84 	 Actual: 140.00
# 40906.)  Predicted: 121.76 	 Actual: 139.00
# 40907.)  Predicted: 77.16 	 Actual: 138.00
# 40908.)  Predicted: 93.72 	 Actual: 137.00
# 40909.)  Predicted: 99.78 	 Actual: 136.00
# 40910.)  Predicted: 144.82 	 Actual: 135.00
# 40911.)  Predicted: 100.58 	 Actual: 134.00
# 40912.)  Predicted: 75.46 	 Actual: 133.00
# 40913.)  Predicted: 81.00 	 Actual: 132.00
# 40914.)  Predicted: 113.74 	 Actual: 131.00
# 40915.)  Predicted: 90.11 	 Actual: 130.00
# 40916.)  Predicted: 84.67 	 Actual: 129.00
# 40917.)  Predicted: 65.27 	 Actual: 128.00
# 40918.)  Predicted: 116.57 	 Actual: 127.00
# 40919.)  Predicted: 110.97 	 Actual: 126.00
# 40920.)  Predicted: 80.98 	 Actual: 125.00
# 40921.)  Predicted: 74.63 	 Actual: 124.00
# 40922.)  Predicted: 119.92 	 Actual: 123.00
# 40923.)  Predicted: 76.67 	 Actual: 122.00
# 40924.)  Predicted: 56.43 	 Actual: 121.00
# 40925.)  Predicted: 86.69 	 Actual: 120.00
# 40926.)  Predicted: 94.74 	 Actual: 119.00
# 40927.)  Predicted: 99.95 	 Actual: 118.00
# 40928.)  Predicted: 96.14 	 Actual: 117.00
# 40929.)  Predicted: 82.69 	 Actual: 116.00
# 40930.)  Predicted: 147.53 	 Actual: 115.00
# 40931.)  Predicted: 82.33 	 Actual: 114.00
# 40932.)  Predicted: 66.34 	 Actual: 113.00
# 40933.)  Predicted: 70.14 	 Actual: 112.00
# 40934.)  Predicted: 173.64 	 Actual: 306.00
# 40935.)  Predicted: 151.69 	 Actual: 305.00
# 40936.)  Predicted: 195.87 	 Actual: 304.00
# 40937.)  Predicted: 164.07 	 Actual: 303.00
# 40938.)  Predicted: 173.58 	 Actual: 302.00
# 40939.)  Predicted: 183.59 	 Actual: 301.00
# 40940.)  Predicted: 202.32 	 Actual: 300.00
# 40941.)  Predicted: 206.58 	 Actual: 299.00
# 40942.)  Predicted: 185.93 	 Actual: 298.00
# 40943.)  Predicted: 190.10 	 Actual: 297.00
# 40944.)  Predicted: 164.16 	 Actual: 296.00
# 40945.)  Predicted: 180.52 	 Actual: 295.00
# 40946.)  Predicted: 135.32 	 Actual: 294.00
# 40947.)  Predicted: 203.36 	 Actual: 293.00
# 40948.)  Predicted: 196.86 	 Actual: 292.00
# 40949.)  Predicted: 203.28 	 Actual: 291.00
# 40950.)  Predicted: 199.08 	 Actual: 290.00
# 40951.)  Predicted: 186.89 	 Actual: 289.00
# 40952.)  Predicted: 196.09 	 Actual: 288.00
# 40953.)  Predicted: 200.41 	 Actual: 287.00
# 40954.)  Predicted: 187.28 	 Actual: 286.00
# 40955.)  Predicted: 181.03 	 Actual: 285.00
# 40956.)  Predicted: 189.16 	 Actual: 284.00
# 40957.)  Predicted: 184.28 	 Actual: 283.00
# 40958.)  Predicted: 178.94 	 Actual: 282.00
# 40959.)  Predicted: 182.96 	 Actual: 281.00
# 40960.)  Predicted: 167.11 	 Actual: 280.00
# 40961.)  Predicted: 149.52 	 Actual: 279.00
# 40962.)  Predicted: 178.19 	 Actual: 278.00
# 40963.)  Predicted: 179.62 	 Actual: 277.00
# 40964.)  Predicted: 196.54 	 Actual: 276.00
# 40965.)  Predicted: 185.82 	 Actual: 275.00
# 40966.)  Predicted: 182.29 	 Actual: 274.00
# 40967.)  Predicted: 174.14 	 Actual: 273.00
# 40968.)  Predicted: 180.39 	 Actual: 272.00
# 40969.)  Predicted: 137.41 	 Actual: 271.00
# 40970.)  Predicted: 191.22 	 Actual: 270.00
# 40971.)  Predicted: 192.45 	 Actual: 269.00
# 40972.)  Predicted: 196.93 	 Actual: 268.00
# 40973.)  Predicted: 165.14 	 Actual: 267.00
# 40974.)  Predicted: 195.66 	 Actual: 266.00
# 40975.)  Predicted: 187.69 	 Actual: 265.00
# 40976.)  Predicted: 185.12 	 Actual: 264.00
# 40977.)  Predicted: 207.43 	 Actual: 263.00
# 40978.)  Predicted: 167.25 	 Actual: 262.00
# 40979.)  Predicted: 137.83 	 Actual: 261.00
# 40980.)  Predicted: 181.24 	 Actual: 260.00
# 40981.)  Predicted: 155.93 	 Actual: 259.00
# 40982.)  Predicted: 188.20 	 Actual: 258.00
# 40983.)  Predicted: 194.38 	 Actual: 257.00
# 40984.)  Predicted: 177.42 	 Actual: 256.00
# 40985.)  Predicted: 168.35 	 Actual: 255.00
# 40986.)  Predicted: 175.05 	 Actual: 254.00
# 40987.)  Predicted: 175.43 	 Actual: 253.00
# 40988.)  Predicted: 207.56 	 Actual: 252.00
# 40989.)  Predicted: 188.07 	 Actual: 251.00
# 40990.)  Predicted: 178.40 	 Actual: 250.00
# 40991.)  Predicted: 150.48 	 Actual: 249.00
# 40992.)  Predicted: 162.86 	 Actual: 248.00
# 40993.)  Predicted: 150.15 	 Actual: 247.00
# 40994.)  Predicted: 168.66 	 Actual: 246.00
# 40995.)  Predicted: 169.59 	 Actual: 245.00
# 40996.)  Predicted: 165.80 	 Actual: 244.00
# 40997.)  Predicted: 179.56 	 Actual: 243.00
# 40998.)  Predicted: 177.03 	 Actual: 242.00
# 40999.)  Predicted: 173.22 	 Actual: 241.00
# 41000.)  Predicted: 175.41 	 Actual: 240.00
# 41001.)  Predicted: 151.64 	 Actual: 239.00
# 41002.)  Predicted: 165.77 	 Actual: 238.00
# 41003.)  Predicted: 198.97 	 Actual: 237.00
# 41004.)  Predicted: 198.63 	 Actual: 236.00
# 41005.)  Predicted: 182.96 	 Actual: 235.00
# 41006.)  Predicted: 149.69 	 Actual: 234.00
# 41007.)  Predicted: 196.41 	 Actual: 233.00
# 41008.)  Predicted: 184.02 	 Actual: 232.00
# 41009.)  Predicted: 173.32 	 Actual: 231.00
# 41010.)  Predicted: 171.54 	 Actual: 230.00
# 41011.)  Predicted: 185.88 	 Actual: 229.00
# 41012.)  Predicted: 168.00 	 Actual: 228.00
# 41013.)  Predicted: 132.03 	 Actual: 227.00
# 41014.)  Predicted: 151.89 	 Actual: 226.00
# 41015.)  Predicted: 167.92 	 Actual: 225.00
# 41016.)  Predicted: 167.80 	 Actual: 224.00
# 41017.)  Predicted: 178.90 	 Actual: 223.00
# 41018.)  Predicted: 182.08 	 Actual: 222.00
# 41019.)  Predicted: 164.34 	 Actual: 221.00
# 41020.)  Predicted: 161.33 	 Actual: 220.00
# 41021.)  Predicted: 170.56 	 Actual: 219.00
# 41022.)  Predicted: 168.52 	 Actual: 218.00
# 41023.)  Predicted: 161.74 	 Actual: 217.00
# 41024.)  Predicted: 178.56 	 Actual: 216.00
# 41025.)  Predicted: 176.88 	 Actual: 215.00
# 41026.)  Predicted: 189.46 	 Actual: 214.00
# 41027.)  Predicted: 157.83 	 Actual: 213.00
# 41028.)  Predicted: 157.83 	 Actual: 212.00
# 41029.)  Predicted: 166.21 	 Actual: 211.00
# 41030.)  Predicted: 190.02 	 Actual: 210.00
# 41031.)  Predicted: 183.84 	 Actual: 209.00
# 41032.)  Predicted: 172.41 	 Actual: 208.00
# 41033.)  Predicted: 168.20 	 Actual: 207.00
# 41034.)  Predicted: 193.90 	 Actual: 206.00
# 41035.)  Predicted: 175.74 	 Actual: 205.00
# 41036.)  Predicted: 150.49 	 Actual: 204.00
# 41037.)  Predicted: 167.95 	 Actual: 203.00
# 41038.)  Predicted: 173.00 	 Actual: 202.00
# 41039.)  Predicted: 163.45 	 Actual: 201.00
# 41040.)  Predicted: 145.86 	 Actual: 200.00
# 41041.)  Predicted: 129.24 	 Actual: 199.00
# 41042.)  Predicted: 178.14 	 Actual: 198.00
# 41043.)  Predicted: 155.33 	 Actual: 197.00
# 41044.)  Predicted: 153.69 	 Actual: 196.00
# 41045.)  Predicted: 173.49 	 Actual: 195.00
# 41046.)  Predicted: 179.28 	 Actual: 194.00
# 41047.)  Predicted: 190.88 	 Actual: 193.00
# 41048.)  Predicted: 173.60 	 Actual: 192.00
# 41049.)  Predicted: 150.54 	 Actual: 191.00
# 41050.)  Predicted: 176.79 	 Actual: 190.00
# 41051.)  Predicted: 158.72 	 Actual: 189.00
# 41052.)  Predicted: 170.43 	 Actual: 188.00
# 41053.)  Predicted: 194.55 	 Actual: 187.00
# 41054.)  Predicted: 183.07 	 Actual: 186.00
# 41055.)  Predicted: 159.48 	 Actual: 185.00
# 41056.)  Predicted: 185.47 	 Actual: 184.00
# 41057.)  Predicted: 171.20 	 Actual: 183.00
# 41058.)  Predicted: 154.24 	 Actual: 182.00
# 41059.)  Predicted: 165.23 	 Actual: 181.00
# 41060.)  Predicted: 152.85 	 Actual: 180.00
# 41061.)  Predicted: 154.05 	 Actual: 179.00
# 41062.)  Predicted: 148.41 	 Actual: 178.00
# 41063.)  Predicted: 186.73 	 Actual: 177.00
# 41064.)  Predicted: 113.10 	 Actual: 176.00
# 41065.)  Predicted: 157.06 	 Actual: 175.00
# 41066.)  Predicted: 162.63 	 Actual: 174.00
# 41067.)  Predicted: 159.57 	 Actual: 173.00
# 41068.)  Predicted: 182.46 	 Actual: 172.00
# 41069.)  Predicted: 167.61 	 Actual: 171.00
# 41070.)  Predicted: 154.66 	 Actual: 170.00
# 41071.)  Predicted: 160.91 	 Actual: 169.00
# 41072.)  Predicted: 149.47 	 Actual: 168.00
# 41073.)  Predicted: 140.73 	 Actual: 167.00
# 41074.)  Predicted: 168.40 	 Actual: 166.00
# 41075.)  Predicted: 131.12 	 Actual: 165.00
# 41076.)  Predicted: 145.79 	 Actual: 164.00
# 41077.)  Predicted: 133.69 	 Actual: 163.00
# 41078.)  Predicted: 172.18 	 Actual: 162.00
# 41079.)  Predicted: 138.36 	 Actual: 161.00
# 41080.)  Predicted: 169.82 	 Actual: 160.00
# 41081.)  Predicted: 136.91 	 Actual: 159.00
# 41082.)  Predicted: 149.79 	 Actual: 158.00
# 41083.)  Predicted: 181.02 	 Actual: 157.00
# 41084.)  Predicted: 132.23 	 Actual: 156.00
# 41085.)  Predicted: 182.68 	 Actual: 155.00
# 41086.)  Predicted: 138.51 	 Actual: 154.00
# 41087.)  Predicted: 108.16 	 Actual: 153.00
# 41088.)  Predicted: 140.23 	 Actual: 152.00
# 41089.)  Predicted: 129.89 	 Actual: 151.00
# 41090.)  Predicted: 138.85 	 Actual: 150.00
# 41091.)  Predicted: 165.95 	 Actual: 149.00
# 41092.)  Predicted: 122.28 	 Actual: 148.00
# 41093.)  Predicted: 146.94 	 Actual: 147.00
# 41094.)  Predicted: 159.20 	 Actual: 146.00
# 41095.)  Predicted: 182.84 	 Actual: 145.00
# 41096.)  Predicted: 122.85 	 Actual: 144.00
# 41097.)  Predicted: 141.17 	 Actual: 143.00
# 41098.)  Predicted: 118.66 	 Actual: 142.00
# 41099.)  Predicted: 165.56 	 Actual: 141.00
# 41100.)  Predicted: 141.93 	 Actual: 140.00
# 41101.)  Predicted: 161.76 	 Actual: 139.00
# 41102.)  Predicted: 144.24 	 Actual: 138.00
# 41103.)  Predicted: 160.61 	 Actual: 137.00
# 41104.)  Predicted: 137.65 	 Actual: 136.00
# 41105.)  Predicted: 162.03 	 Actual: 135.00
# 41106.)  Predicted: 146.39 	 Actual: 134.00
# 41107.)  Predicted: 171.06 	 Actual: 133.00
# 41108.)  Predicted: 173.12 	 Actual: 132.00
# 41109.)  Predicted: 128.74 	 Actual: 131.00
# 41110.)  Predicted: 98.79 	 Actual: 130.00
# 41111.)  Predicted: 156.08 	 Actual: 129.00
# 41112.)  Predicted: 151.45 	 Actual: 128.00
# 41113.)  Predicted: 121.67 	 Actual: 127.00
# 41114.)  Predicted: 111.42 	 Actual: 126.00
# 41115.)  Predicted: 115.74 	 Actual: 125.00
# 41116.)  Predicted: 133.02 	 Actual: 124.00
# 41117.)  Predicted: 144.04 	 Actual: 123.00
# 41118.)  Predicted: 150.36 	 Actual: 122.00
# 41119.)  Predicted: 162.03 	 Actual: 121.00
# 41120.)  Predicted: 131.26 	 Actual: 120.00
# 41121.)  Predicted: 135.73 	 Actual: 119.00
# 41122.)  Predicted: 108.47 	 Actual: 118.00
# 41123.)  Predicted: 108.03 	 Actual: 117.00
# 41124.)  Predicted: 142.31 	 Actual: 116.00
# 41125.)  Predicted: 140.23 	 Actual: 115.00
# 41126.)  Predicted: 133.02 	 Actual: 114.00
# 41127.)  Predicted: 124.71 	 Actual: 113.00
# 41128.)  Predicted: 104.05 	 Actual: 112.00
# 41129.)  Predicted: 108.55 	 Actual: 111.00
# 41130.)  Predicted: 145.93 	 Actual: 110.00
# 41131.)  Predicted: 91.04 	 Actual: 109.00
# 41132.)  Predicted: 109.25 	 Actual: 108.00
# 41133.)  Predicted: 109.49 	 Actual: 107.00
# 41134.)  Predicted: 96.95 	 Actual: 106.00
# 41135.)  Predicted: 118.11 	 Actual: 105.00
# 41136.)  Predicted: 98.95 	 Actual: 104.00
# 41137.)  Predicted: 86.21 	 Actual: 103.00
# 41138.)  Predicted: 101.87 	 Actual: 102.00
# 41139.)  Predicted: 79.50 	 Actual: 101.00
# 41140.)  Predicted: 124.48 	 Actual: 100.00
# 41141.)  Predicted: 108.27 	 Actual: 99.00
# 41142.)  Predicted: 86.94 	 Actual: 98.00
# 41143.)  Predicted: 102.47 	 Actual: 97.00
# 41144.)  Predicted: 125.20 	 Actual: 96.00
# 41145.)  Predicted: 96.10 	 Actual: 95.00
# 41146.)  Predicted: 106.28 	 Actual: 94.00
# 41147.)  Predicted: 111.77 	 Actual: 93.00
# 41148.)  Predicted: 92.41 	 Actual: 92.00
# 41149.)  Predicted: 70.32 	 Actual: 91.00
# 41150.)  Predicted: 98.18 	 Actual: 90.00
# 41151.)  Predicted: 93.49 	 Actual: 89.00
# 41152.)  Predicted: 65.29 	 Actual: 88.00
# 41153.)  Predicted: 126.56 	 Actual: 87.00
# 41154.)  Predicted: 120.50 	 Actual: 86.00
# 41155.)  Predicted: 85.14 	 Actual: 85.00
# 41156.)  Predicted: 108.81 	 Actual: 84.00
# 41157.)  Predicted: 53.51 	 Actual: 83.00
# 41158.)  Predicted: 96.58 	 Actual: 82.00
# 41159.)  Predicted: 74.04 	 Actual: 81.00
# 41160.)  Predicted: 110.84 	 Actual: 80.00
# 41161.)  Predicted: 72.45 	 Actual: 79.00
# 41162.)  Predicted: 57.99 	 Actual: 78.00
# 41163.)  Predicted: 71.36 	 Actual: 77.00
# 41164.)  Predicted: 57.66 	 Actual: 76.00
# 41165.)  Predicted: 93.83 	 Actual: 75.00
# 41166.)  Predicted: 73.10 	 Actual: 74.00
# 41167.)  Predicted: 65.20 	 Actual: 73.00
# 41168.)  Predicted: 70.23 	 Actual: 72.00
# 41169.)  Predicted: 74.64 	 Actual: 71.00
# 41170.)  Predicted: 82.18 	 Actual: 70.00
# 41171.)  Predicted: 46.03 	 Actual: 69.00
# 41172.)  Predicted: 40.00 	 Actual: 68.00
# 41173.)  Predicted: 84.39 	 Actual: 67.00
# 41174.)  Predicted: 67.11 	 Actual: 66.00
# 41175.)  Predicted: 52.41 	 Actual: 65.00
# 41176.)  Predicted: 69.13 	 Actual: 64.00
# 41177.)  Predicted: 62.37 	 Actual: 63.00
# 41178.)  Predicted: 46.21 	 Actual: 62.00
# 41179.)  Predicted: 55.43 	 Actual: 61.00
# 41180.)  Predicted: 32.45 	 Actual: 60.00
# 41181.)  Predicted: 60.28 	 Actual: 59.00
# 41182.)  Predicted: 30.85 	 Actual: 58.00
# 41183.)  Predicted: 73.99 	 Actual: 57.00
# 41184.)  Predicted: 36.70 	 Actual: 56.00
# 41185.)  Predicted: 27.43 	 Actual: 55.00
# 41186.)  Predicted: 23.46 	 Actual: 54.00
# 41187.)  Predicted: 44.83 	 Actual: 53.00
# 41188.)  Predicted: 54.21 	 Actual: 52.00
# 41189.)  Predicted: 28.84 	 Actual: 51.00
# 41190.)  Predicted: 42.93 	 Actual: 50.00
# 41191.)  Predicted: 35.87 	 Actual: 49.00
# 41192.)  Predicted: 38.52 	 Actual: 48.00
# 41193.)  Predicted: 56.86 	 Actual: 47.00
# 41194.)  Predicted: 24.46 	 Actual: 46.00
# 41195.)  Predicted: 26.97 	 Actual: 45.00
# 41196.)  Predicted: 30.16 	 Actual: 44.00
# 41197.)  Predicted: 22.56 	 Actual: 43.00
# 41198.)  Predicted: 29.56 	 Actual: 42.00
# 41199.)  Predicted: 28.45 	 Actual: 41.00
# 41200.)  Predicted: 21.86 	 Actual: 40.00
# 41201.)  Predicted: 18.21 	 Actual: 39.00
# 41202.)  Predicted: 22.75 	 Actual: 38.00
# 41203.)  Predicted: 22.07 	 Actual: 37.00
# 41204.)  Predicted: 26.55 	 Actual: 36.00
# 41205.)  Predicted: 35.54 	 Actual: 35.00
# 41206.)  Predicted: 26.17 	 Actual: 34.00
# 41207.)  Predicted: 20.09 	 Actual: 33.00
# 41208.)  Predicted: 23.51 	 Actual: 32.00
# 41209.)  Predicted: 19.49 	 Actual: 31.00
# 41210.)  Predicted: 26.56 	 Actual: 30.00
# 41211.)  Predicted: 27.60 	 Actual: 29.00
# 41212.)  Predicted: 21.20 	 Actual: 28.00
# 41213.)  Predicted: 26.06 	 Actual: 27.00
# 41214.)  Predicted: 21.12 	 Actual: 26.00
#
# Mean Absolute Error: 57.23

# %%
# Generate predictions for all test data
model.eval()
with torch.no_grad():
    y_predictions = model.forward(X_test).squeeze().numpy()

# Get unique engines and randomly select 8
unique_engines = Testing_df['engine'].unique()
np.random.seed(42)  # For reproducibility
selected_engines = np.random.choice(unique_engines, size=min(8, len(unique_engines)), replace=False)

# Create a figure with 8 subplots (2 rows x 4 columns)
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
fig.suptitle('Neural Network - Actual vs Predicted RUL for Random Engines', fontsize=16, y=1.00)

# Flatten axes array for easier iteration
axes = axes.flatten()

# Plot each selected engine
for idx, engine_num in enumerate(selected_engines):
    # Filter for current engine
    engine_mask = Testing_df['engine'] == engine_num
    engine_df = Testing_df[engine_mask]
    
    # Extract cycle data and RUL values
    X_og = engine_df['cycle'].values
    Y_og = engine_df['RUL'].values
    
    # Get predictions for current engine
    y_pred_engine = y_predictions[engine_mask]
    
    # Plot on the corresponding subplot
    axes[idx].scatter(X_og, Y_og, label='Actual RUL', color='blue', alpha=0.7, marker='x')
    axes[idx].scatter(X_og, y_pred_engine, label='Predicted RUL', color='red', alpha=0.7)
    axes[idx].set_title(f'Engine {engine_num}')
    axes[idx].set_xlabel('Cycle Count')
    axes[idx].set_ylabel('RUL')
    axes[idx].set_ylim(0, 260)  # Set y-axis limits from 0 to 260
    axes[idx].legend(fontsize=8)
    axes[idx].grid(True, alpha=0.3)
    
    # Calculate and display MAE for this engine
    mae_engine = np.mean(np.abs(Y_og - y_pred_engine))
    axes[idx].text(0.05, 0.95, f'MAE: {mae_engine:.2f}', 
                   transform=axes[idx].transAxes, 
                   verticalalignment='top',
                   bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5),
                   fontsize=8)

plt.tight_layout()
plt.show()

# Print summary statistics for all selected engines
print("Summary Statistics for Selected Engines:")
print("="*60)
for engine_num in selected_engines:
    engine_mask = Testing_df['engine'] == engine_num
    Y_og = Testing_df[engine_mask]['RUL'].values
    y_pred_engine = y_predictions[engine_mask]
    
    mae = np.mean(np.abs(Y_og - y_pred_engine))
    errors = (Y_og - y_pred_engine) / Y_og * 100
    avg_error = np.mean(np.abs(errors))
    
    print(f"Engine {engine_num}: MAE = {mae:.2f} cycles, Avg Error = {avg_error:.2f}%")
# Out:
# Summary Statistics for Selected Engines:
# ============================================================
# Engine 34: MAE = 96.47 cycles, Avg Error = 27.68%
# Engine 7: MAE = 30.63 cycles, Avg Error = 24.80%
# Engine 183: MAE = 48.99 cycles, Avg Error = 101.44%
# Engine 87: MAE = 41.31 cycles, Avg Error = 27.39%
# Engine 157: MAE = 36.72 cycles, Avg Error = 14.55%
# Engine 247: MAE = 52.56 cycles, Avg Error = 32.47%
# Engine 196: MAE = 33.27 cycles, Avg Error = 29.26%
# Engine 105: MAE = 111.77 cycles, Avg Error = 35.14%

# %%
# Generate predictions for engines with the 8 lowest final RUL values
model.eval()
with torch.no_grad():
    y_predictions = model.forward(X_test).squeeze().numpy()

# Get final RUL for each engine and sort to find the 8 lowest
engine_final_rul = []
for engine_num in Testing_df['engine'].unique():
    engine_data = Testing_df[Testing_df['engine'] == engine_num]
    last_rul = engine_data['RUL'].iloc[-1]  # Get the last RUL value
    engine_final_rul.append((engine_num, last_rul))

# Sort by final RUL (ascending) and select the 8 engines with lowest final RUL
engine_final_rul.sort(key=lambda x: x[1])
selected_engines = [engine_num for engine_num, _ in engine_final_rul[:8]]

print(f"8 Engines with lowest final RUL:")
for engine_num, final_rul in engine_final_rul[:8]:
    print(f"  Engine {engine_num}: Final RUL = {final_rul:.1f}")

# Create a figure with 8 subplots (2 rows x 4 columns)
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
fig.suptitle('Neural Network - 8 Engines with Lowest Final RUL', fontsize=16, y=1.00)

# Flatten axes array for easier iteration
axes = axes.flatten()

# Plot each selected engine
for idx, engine_num in enumerate(selected_engines):
    # Filter for current engine
    engine_mask = Testing_df['engine'] == engine_num
    engine_df = Testing_df[engine_mask]
    
    # Extract cycle data and RUL values
    X_og = engine_df['cycle'].values
    Y_og = engine_df['RUL'].values
    
    # Get predictions for current engine
    y_pred_engine = y_predictions[engine_mask]
    
    # Get final RUL value
    final_rul = Y_og[-1]
    
    # Plot on the corresponding subplot
    axes[idx].scatter(X_og, Y_og, label='Actual RUL', color='blue', alpha=0.7, marker='x')
    axes[idx].scatter(X_og, y_pred_engine, label='Predicted RUL', color='red', alpha=0.7)
    axes[idx].set_title(f'Engine {engine_num} (Final RUL: {final_rul:.1f})')
    axes[idx].set_xlabel('Cycle Count')
    axes[idx].set_ylabel('RUL')
    axes[idx].set_ylim(0, 260)  # Set y-axis limits from 0 to 260
    axes[idx].legend(fontsize=8)
    axes[idx].grid(True, alpha=0.3)
    
    # Calculate and display MAE for this engine
    mae_engine = np.mean(np.abs(Y_og - y_pred_engine))
    axes[idx].text(0.05, 0.95, f'MAE: {mae_engine:.2f}', 
                   transform=axes[idx].transAxes, 
                   verticalalignment='top',
                   bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5),
                   fontsize=8)

plt.tight_layout()
plt.show()

# Print summary statistics for all selected engines
print("\nSummary Statistics for 8 Engines with Lowest Final RUL:")
print("="*60)
for engine_num in selected_engines:
    engine_mask = Testing_df['engine'] == engine_num
    engine_df = Testing_df[engine_mask]
    Y_og = engine_df['RUL'].values
    y_pred_engine = y_predictions[engine_mask]
    final_rul = Y_og[-1]
    
    mae = np.mean(np.abs(Y_og - y_pred_engine))
    errors = (Y_og - y_pred_engine) / Y_og * 100
    avg_error = np.mean(np.abs(errors))
    
    print(f"Engine {engine_num} (Final RUL: {final_rul:.1f}): MAE = {mae:.2f} cycles, Avg Error = {avg_error:.2f}%")
# Out:
# 8 Engines with lowest final RUL:
#   Engine 31: Final RUL = 6.0
#   Engine 158: Final RUL = 6.0
#   Engine 12: Final RUL = 7.0
#   Engine 100: Final RUL = 7.0
#   Engine 135: Final RUL = 7.0
#   Engine 155: Final RUL = 7.0
#   Engine 58: Final RUL = 8.0
#   Engine 118: Final RUL = 8.0
# Summary Statistics for 8 Engines with Lowest Final RUL:
# ============================================================
# Engine 31 (Final RUL: 6.0): MAE = 35.69 cycles, Avg Error = 74.59%
# Engine 158 (Final RUL: 6.0): MAE = 34.89 cycles, Avg Error = 63.54%
# Engine 12 (Final RUL: 7.0): MAE = 58.56 cycles, Avg Error = 66.00%
# Engine 100 (Final RUL: 7.0): MAE = 62.53 cycles, Avg Error = 85.81%
# Engine 135 (Final RUL: 7.0): MAE = 74.23 cycles, Avg Error = 28.68%
# Engine 155 (Final RUL: 7.0): MAE = 39.67 cycles, Avg Error = 61.07%
# Engine 58 (Final RUL: 8.0): MAE = 32.55 cycles, Avg Error = 60.39%
# Engine 118 (Final RUL: 8.0): MAE = 48.87 cycles, Avg Error = 69.81%
